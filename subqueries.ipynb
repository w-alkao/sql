# %%
# %load_ext sql

# %%
# %%sql
# mysql+pymysql://w-alkao:mypassword@localhost

# %%
# %sql SHOW DATABASES;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 8 rows affected.
# [('ap',),
#  ('ex',),
#  ('information_schema',),
#  ('livestock',),
#  ('mysql',),
#  ('om',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %sql USE ap
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# ### Intro to subqueries

# %%
# %%sql # A query that uses an inner join that retrieve invoice number, invoice date and invoice total for vendor in CA region
#
# SELECT invoice_number, invoice_date, invoice_total
# FROM Invoices i
#   JOIN Vendors v ON i.vendor_id = v.vendor_id
# WHERE vendor_state = 'CA'
# ORDER BY invoice_date
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 40 rows affected.
# [('97/488', datetime.date(2018, 4, 24), Decimal('601.95')),
#  ('125520-1', datetime.date(2018, 4, 24), Decimal('95.00')),
#  ('111-92R-10096', datetime.date(2018, 4, 30), Decimal('16.33')),
#  ('25022117', datetime.date(2018, 5, 1), Decimal('6.00')),
#  ('P02-88D77S7', datetime.date(2018, 5, 3), Decimal('856.92')),
#  ('QP58872', datetime.date(2018, 5, 7), Decimal('116.54')),
#  ('24863706', datetime.date(2018, 5, 10), Decimal('6.00')),
#  ('10843', datetime.date(2018, 5, 11), Decimal('4901.26')),
#  ('77290', datetime.date(2018, 5, 13), Decimal('1750.00')),
#  ('121897', datetime.date(2018, 5, 19), Decimal('450.00')),
#  ('97/486', datetime.date(2018, 5, 21), Decimal('953.10')),
#  ('P02-3772', datetime.date(2018, 5, 21), Decimal('7125.34')),
#  ('94007005', datetime.date(2018, 5, 23), Decimal('220.00')),
#  ('97/465', datetime.date(2018, 5, 25), Decimal('565.15')),
#  ('RTR-72-3662-X', datetime.date(2018, 5, 25), Decimal('1600.00')),
#  ('97/503', datetime.date(2018, 5, 30), Decimal('639.77')),
#  ('111-92R-10094', datetime.date(2018, 6, 1), Decimal('19.67')),
#  ('547481328', datetime.date(2018, 6, 3), Decimal('224.00')),
#  ('111-92R-10097', datetime.date(2018, 6, 4), Decimal('16.33')),
#  ('547479217', datetime.date(2018, 6, 7), Decimal('116.00')),
#  ('Q545443', datetime.date(2018, 6, 9), Decimal('1083.58')),
#  ('111-92R-10092', datetime.date(2018, 6, 9), Decimal('46.21')),
#  ('97/553B', datetime.date(2018, 6, 10), Decimal('313.55')),
#  ('367447', datetime.date(2018, 6, 11), Decimal('2433.00')),
#  ('24946731', datetime.date(2018, 6, 15), Decimal('25.67')),
#  ('509786', datetime.date(2018, 6, 18), Decimal('6940.25')),
#  ('MABO1489', datetime.date(2018, 6, 21), Decimal('936.93')),
#  ('24780512', datetime.date(2018, 6, 22), Decimal('6.00')),
#  ('CBM9920-M-T77109', datetime.date(2018, 6, 23), Decimal('290.00')),
#  ('109596', datetime.date(2018, 6, 24), Decimal('41.80')),
#  ('97/553', datetime.date(2018, 6, 25), Decimal('904.14')),
#  ('97/522', datetime.date(2018, 6, 28), Decimal('1962.13')),
#  ('203339-13', datetime.date(2018, 7, 5), Decimal('17.50')),
#  ('111-92R-10093', datetime.date(2018, 7, 6), Decimal('39.77')),
#  ('111897', datetime.date(2018, 7, 15), Decimal('16.62')),
#  ('111-92R-10095', datetime.date(2018, 7, 15), Decimal('32.70')),
#  ('97-1024A', datetime.date(2018, 7, 20), Decimal('356.48')),
#  ('9982771', datetime.date(2018, 7, 24), Decimal('503.20')),
#  ('97/222', datetime.date(2018, 7, 25), Decimal('1000.46')),
#  ('547480102', datetime.date(2018, 8, 1), Decimal('224.00'))]

# %%
# %%sql # The same query restated with a subquery
#
# SELECT invoice_number, invoice_date, invoice_total
# FROM Invoices
# WHERE vendor_id IN (
#   SELECT vendor_id
#   FROM Vendors
#   WHERE vendor_state = 'CA')
# ORDER BY invoice_date;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 40 rows affected.
# [('97/488', datetime.date(2018, 4, 24), Decimal('601.95')),
#  ('125520-1', datetime.date(2018, 4, 24), Decimal('95.00')),
#  ('111-92R-10096', datetime.date(2018, 4, 30), Decimal('16.33')),
#  ('25022117', datetime.date(2018, 5, 1), Decimal('6.00')),
#  ('P02-88D77S7', datetime.date(2018, 5, 3), Decimal('856.92')),
#  ('QP58872', datetime.date(2018, 5, 7), Decimal('116.54')),
#  ('24863706', datetime.date(2018, 5, 10), Decimal('6.00')),
#  ('10843', datetime.date(2018, 5, 11), Decimal('4901.26')),
#  ('77290', datetime.date(2018, 5, 13), Decimal('1750.00')),
#  ('121897', datetime.date(2018, 5, 19), Decimal('450.00')),
#  ('97/486', datetime.date(2018, 5, 21), Decimal('953.10')),
#  ('P02-3772', datetime.date(2018, 5, 21), Decimal('7125.34')),
#  ('94007005', datetime.date(2018, 5, 23), Decimal('220.00')),
#  ('97/465', datetime.date(2018, 5, 25), Decimal('565.15')),
#  ('RTR-72-3662-X', datetime.date(2018, 5, 25), Decimal('1600.00')),
#  ('97/503', datetime.date(2018, 5, 30), Decimal('639.77')),
#  ('111-92R-10094', datetime.date(2018, 6, 1), Decimal('19.67')),
#  ('547481328', datetime.date(2018, 6, 3), Decimal('224.00')),
#  ('111-92R-10097', datetime.date(2018, 6, 4), Decimal('16.33')),
#  ('547479217', datetime.date(2018, 6, 7), Decimal('116.00')),
#  ('Q545443', datetime.date(2018, 6, 9), Decimal('1083.58')),
#  ('111-92R-10092', datetime.date(2018, 6, 9), Decimal('46.21')),
#  ('97/553B', datetime.date(2018, 6, 10), Decimal('313.55')),
#  ('367447', datetime.date(2018, 6, 11), Decimal('2433.00')),
#  ('24946731', datetime.date(2018, 6, 15), Decimal('25.67')),
#  ('509786', datetime.date(2018, 6, 18), Decimal('6940.25')),
#  ('MABO1489', datetime.date(2018, 6, 21), Decimal('936.93')),
#  ('24780512', datetime.date(2018, 6, 22), Decimal('6.00')),
#  ('CBM9920-M-T77109', datetime.date(2018, 6, 23), Decimal('290.00')),
#  ('109596', datetime.date(2018, 6, 24), Decimal('41.80')),
#  ('97/553', datetime.date(2018, 6, 25), Decimal('904.14')),
#  ('97/522', datetime.date(2018, 6, 28), Decimal('1962.13')),
#  ('203339-13', datetime.date(2018, 7, 5), Decimal('17.50')),
#  ('111-92R-10093', datetime.date(2018, 7, 6), Decimal('39.77')),
#  ('111897', datetime.date(2018, 7, 15), Decimal('16.62')),
#  ('111-92R-10095', datetime.date(2018, 7, 15), Decimal('32.70')),
#  ('97-1024A', datetime.date(2018, 7, 20), Decimal('356.48')),
#  ('9982771', datetime.date(2018, 7, 24), Decimal('503.20')),
#  ('97/222', datetime.date(2018, 7, 25), Decimal('1000.46')),
#  ('547480102', datetime.date(2018, 8, 1), Decimal('224.00'))]

# %% [markdown]
# ### Subqueries in the Where clause

# %%
# %%sql # Get vendors without invoices
#
# SELECT vendor_id, vendor_name, vendor_state
# FROM Vendors
# WHERE vendor_id NOT IN (
#   SELECT DISTINCT vendor_id
#   FROM Invoices)
# ORDER BY vendor_id;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 88 rows affected.
# [(1, 'US Postal Service', 'WI'),
#  (2, 'National Information Data Ctr', 'DC'),
#  (3, 'Register of Copyrights', 'DC'),
#  (4, 'Jobtrak', 'CA'),
#  (5, 'Newbrige Book Clubs', 'NJ'),
#  (6, 'California Chamber Of Commerce', 'CA'),
#  (7, "Towne Advertiser's Mailing Svcs", 'CA'),
#  (8, 'BFI Industries', 'CA'),
#  (9, 'Pacific Gas & Electric', 'CA'),
#  (10, 'Robbins Mobile Lock And Key', 'CA'),
#  (11, 'Bill Marvin Electric Inc', 'CA'),
#  (12, 'City Of Fresno', 'CA'),
#  (13, 'Golden Eagle Insurance Co', 'CA'),
#  (14, 'Expedata Inc', 'CA'),
#  (15, 'ASC Signs', 'CA'),
#  (16, 'Internal Revenue Service', 'CA'),
#  (17, 'Blanchard & Johnson Associates', 'CA'),
#  (18, 'Fresno Photoengraving Company', 'CA'),
#  (19, 'Crown Printing', 'CA'),
#  (20, 'Diversified Printing & Pub', 'CA'),
#  (21, 'The Library Ltd', 'MO'),
#  (22, 'Micro Center', 'OH'),
#  (23, 'Yale Industrial Trucks-Fresno', 'CA'),
#  (24, 'Zee Medical Service Co', 'IA'),
#  (25, 'California Data Marketing', 'CA'),
#  (26, 'Small Press', 'MI'),
#  (27, 'Rich Advertising', 'NJ'),
#  (29, 'Vision Envelope & Printing', 'CA'),
#  (30, 'Costco', 'CA'),
#  (31, 'Enterprise Communications Inc', 'VA'),
#  (32, 'RR Bowker', 'NJ'),
#  (33, 'Nielson', 'OH'),
#  (35, 'Cal State Termite', 'CA'),
#  (36, 'Graylift', 'CA'),
#  (38, "Venture Communications Int'l", 'NY'),
#  (39, 'Custom Printing Company', 'MO'),
#  (40, 'Nat Assoc of College Stores', 'OH'),
#  (41, 'Shields Design', 'CA'),
#  (42, 'Opamp Technical Books', 'CA'),
#  (43, 'Capital Resource Credit', 'MN'),
#  (44, 'Courier Companies, Inc', 'MA'),
#  (45, 'Naylor Publications Inc', 'FL'),
#  (46, 'Open Horizons Publishing', 'IA'),
#  (47, 'Baker & Taylor Books', 'NC'),
#  (49, 'Mcgraw Hill Companies', 'IL'),
#  (50, 'Publishers Weekly', 'OH'),
#  (51, 'Blue Shield of California', 'CA'),
#  (52, 'Aztek Label', 'CA'),
#  (53, 'Gary McKeighan Insurance', 'CA'),
#  (54, 'Ph Photographic Services', 'CA'),
#  (55, 'Quality Education Data', 'IL'),
#  (56, 'Springhouse Corp', 'PA'),
#  (57, 'The Windows Deck', 'CA'),
#  (58, 'Fresno Rack & Shelving Inc', 'CA'),
#  (59, 'Publishers Marketing Assoc', 'CA'),
#  (60, 'The Mailers Guide Co', 'NY'),
#  (61, 'American Booksellers Assoc', 'NY'),
#  (62, 'Cmg Information Services', 'MA'),
#  (63, "Lou Gentile's Flower Basket", 'CA'),
#  (64, 'Texaco', 'CA'),
#  (65, 'The Drawing Board', 'IL'),
#  (66, 'Ascom Hasler Mailing Systems', 'CT'),
#  (67, 'Bill Jones', 'CA'),
#  (68, 'Computer Library', 'AZ'),
#  (69, 'Frank E Wilber Co', 'CA'),
#  (70, 'Fresno Credit Bureau', 'CA'),
#  (71, 'The Fresno Bee', 'CA'),
#  (73, 'Executive Office Products', 'CA'),
#  (74, 'Leslie Company', 'KS'),
#  (75, 'Retirement Plan Consultants', 'CA'),
#  (76, 'Simon Direct Inc', 'NJ'),
#  (77, 'State Board Of Equalization', 'CA'),
#  (78, 'The Presort Center', 'CA'),
#  (79, 'Valprint', 'CA'),
#  (84, 'Boucher Communications Inc', 'PA'),
#  (85, 'Champion Printing Company', 'OH'),
#  (87, 'DMV Renewal', 'CA'),
#  (91, 'McKesson Water Products', 'CA'),
#  (92, 'Zip Print & Copy Center', 'CA'),
#  (93, 'AT&T', 'AZ'),
#  (98, 'American Express', 'CA'),
#  (101, 'California Business Machines', 'CA'),
#  (109, 'Kent H Landsberg Co', 'CA'),
#  (111, 'Net Asset, Llc', 'CA'),
#  (112, 'Office Depot', 'CA'),
#  (116, 'State of California', 'CA'),
#  (118, 'Unocal', 'CA'),
#  (120, 'Dataforms/West', 'CA')]

# %%
# %%sql # Same query without a subquery
#
# SELECT v.vendor_id, vendor_name, vendor_state
# FROM Vendors v
#   LEFT JOIN Invoices i ON v.vendor_id = i.vendor_id
# WHERE i.vendor_id IS NULL
# ORDER BY v.vendor_id;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 88 rows affected.
# [(1, 'US Postal Service', 'WI'),
#  (2, 'National Information Data Ctr', 'DC'),
#  (3, 'Register of Copyrights', 'DC'),
#  (4, 'Jobtrak', 'CA'),
#  (5, 'Newbrige Book Clubs', 'NJ'),
#  (6, 'California Chamber Of Commerce', 'CA'),
#  (7, "Towne Advertiser's Mailing Svcs", 'CA'),
#  (8, 'BFI Industries', 'CA'),
#  (9, 'Pacific Gas & Electric', 'CA'),
#  (10, 'Robbins Mobile Lock And Key', 'CA'),
#  (11, 'Bill Marvin Electric Inc', 'CA'),
#  (12, 'City Of Fresno', 'CA'),
#  (13, 'Golden Eagle Insurance Co', 'CA'),
#  (14, 'Expedata Inc', 'CA'),
#  (15, 'ASC Signs', 'CA'),
#  (16, 'Internal Revenue Service', 'CA'),
#  (17, 'Blanchard & Johnson Associates', 'CA'),
#  (18, 'Fresno Photoengraving Company', 'CA'),
#  (19, 'Crown Printing', 'CA'),
#  (20, 'Diversified Printing & Pub', 'CA'),
#  (21, 'The Library Ltd', 'MO'),
#  (22, 'Micro Center', 'OH'),
#  (23, 'Yale Industrial Trucks-Fresno', 'CA'),
#  (24, 'Zee Medical Service Co', 'IA'),
#  (25, 'California Data Marketing', 'CA'),
#  (26, 'Small Press', 'MI'),
#  (27, 'Rich Advertising', 'NJ'),
#  (29, 'Vision Envelope & Printing', 'CA'),
#  (30, 'Costco', 'CA'),
#  (31, 'Enterprise Communications Inc', 'VA'),
#  (32, 'RR Bowker', 'NJ'),
#  (33, 'Nielson', 'OH'),
#  (35, 'Cal State Termite', 'CA'),
#  (36, 'Graylift', 'CA'),
#  (38, "Venture Communications Int'l", 'NY'),
#  (39, 'Custom Printing Company', 'MO'),
#  (40, 'Nat Assoc of College Stores', 'OH'),
#  (41, 'Shields Design', 'CA'),
#  (42, 'Opamp Technical Books', 'CA'),
#  (43, 'Capital Resource Credit', 'MN'),
#  (44, 'Courier Companies, Inc', 'MA'),
#  (45, 'Naylor Publications Inc', 'FL'),
#  (46, 'Open Horizons Publishing', 'IA'),
#  (47, 'Baker & Taylor Books', 'NC'),
#  (49, 'Mcgraw Hill Companies', 'IL'),
#  (50, 'Publishers Weekly', 'OH'),
#  (51, 'Blue Shield of California', 'CA'),
#  (52, 'Aztek Label', 'CA'),
#  (53, 'Gary McKeighan Insurance', 'CA'),
#  (54, 'Ph Photographic Services', 'CA'),
#  (55, 'Quality Education Data', 'IL'),
#  (56, 'Springhouse Corp', 'PA'),
#  (57, 'The Windows Deck', 'CA'),
#  (58, 'Fresno Rack & Shelving Inc', 'CA'),
#  (59, 'Publishers Marketing Assoc', 'CA'),
#  (60, 'The Mailers Guide Co', 'NY'),
#  (61, 'American Booksellers Assoc', 'NY'),
#  (62, 'Cmg Information Services', 'MA'),
#  (63, "Lou Gentile's Flower Basket", 'CA'),
#  (64, 'Texaco', 'CA'),
#  (65, 'The Drawing Board', 'IL'),
#  (66, 'Ascom Hasler Mailing Systems', 'CT'),
#  (67, 'Bill Jones', 'CA'),
#  (68, 'Computer Library', 'AZ'),
#  (69, 'Frank E Wilber Co', 'CA'),
#  (70, 'Fresno Credit Bureau', 'CA'),
#  (71, 'The Fresno Bee', 'CA'),
#  (73, 'Executive Office Products', 'CA'),
#  (74, 'Leslie Company', 'KS'),
#  (75, 'Retirement Plan Consultants', 'CA'),
#  (76, 'Simon Direct Inc', 'NJ'),
#  (77, 'State Board Of Equalization', 'CA'),
#  (78, 'The Presort Center', 'CA'),
#  (79, 'Valprint', 'CA'),
#  (84, 'Boucher Communications Inc', 'PA'),
#  (85, 'Champion Printing Company', 'OH'),
#  (87, 'DMV Renewal', 'CA'),
#  (91, 'McKesson Water Products', 'CA'),
#  (92, 'Zip Print & Copy Center', 'CA'),
#  (93, 'AT&T', 'AZ'),
#  (98, 'American Express', 'CA'),
#  (101, 'California Business Machines', 'CA'),
#  (109, 'Kent H Landsberg Co', 'CA'),
#  (111, 'Net Asset, Llc', 'CA'),
#  (112, 'Office Depot', 'CA'),
#  (116, 'State of California', 'CA'),
#  (118, 'Unocal', 'CA'),
#  (120, 'Dataforms/West', 'CA')]

# %%
# %%sql # Get invoices with a balance due less than the average
#
# SELECT invoice_number, invoice_date,
#   invoice_total - payment_total - credit_total AS balance_due
# FROM Invoices
# WHERE invoice_total - payment_total - credit_total > 0
#   AND invoice_total - payment_total - credit_total < (
#     SELECT AVG(invoice_total - payment_total - credit_total)
#     FROM Invoices
#     WHERE invoice_total - payment_total - credit_total > 0)
# ORDER BY invoice_total DESC;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 11 rows affected.
# [('31361833', datetime.date(2018, 7, 21), Decimal('579.42')),
#  ('456792', datetime.date(2018, 8, 3), Decimal('565.60')),
#  ('9982771', datetime.date(2018, 7, 24), Decimal('503.20')),
#  ('456701', datetime.date(2018, 8, 2), Decimal('270.50')),
#  ('547480102', datetime.date(2018, 8, 1), Decimal('224.00')),
#  ('134116', datetime.date(2018, 7, 28), Decimal('90.36')),
#  ('39104', datetime.date(2018, 7, 10), Decimal('85.31')),
#  ('263253270', datetime.date(2018, 7, 22), Decimal('67.92')),
#  ('263253268', datetime.date(2018, 7, 21), Decimal('59.97')),
#  ('963253264', datetime.date(2018, 7, 18), Decimal('52.25')),
#  ('263253273', datetime.date(2018, 7, 22), Decimal('30.75'))]

# %%
# %%sql # Get invoices larger than the largest invoice for vendor 34
#
# SELECT vendor_name, invoice_number, invoice_total
# FROM Invoices i
#   JOIN Vendors v ON i.vendor_id = v.vendor_id
# WHERE invoice_total > ALL (
#   SELECT invoice_total
#   FROM Invoices
#   WHERE vendor_id = 34)
# ORDER BY vendor_name;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 28 rows affected.
# [('Bertelsmann Industry Svcs. Inc', '509786', Decimal('6940.25')),
#  ('Cahners Publishing Company', '587056', Decimal('2184.50')),
#  ('Compuserve', '456791', Decimal('4390.00')),
#  ('Compuserve', '456789', Decimal('8344.50')),
#  ('Compuserve', '456789', Decimal('8344.50')),
#  ('Computerworld', '367447', Decimal('2433.00')),
#  ('Data Reproductions Corp', '40318', Decimal('21842.00')),
#  ('Dean Witter Reynolds', '75C-90227', Decimal('1367.50')),
#  ('Digital Dreamworks', 'P02-3772', Decimal('7125.34')),
#  ('Franchise Tax Board', 'RTR-72-3662-X', Decimal('1600.00')),
#  ('Ingram', '31359783', Decimal('1575.00')),
#  ('Malloy Lithographing Inc', '0-2058', Decimal('37966.19')),
#  ('Malloy Lithographing Inc', '0-2436', Decimal('10976.06')),
#  ('Malloy Lithographing Inc', '0-2060', Decimal('23517.58')),
#  ('Malloy Lithographing Inc', 'P-0608', Decimal('20551.18')),
#  ('Malloy Lithographing Inc', 'P-0259', Decimal('26881.40')),
#  ('Pollstar', '77290', Decimal('1750.00')),
#  ('United Parcel Service', '989319-457', Decimal('3813.33')),
#  ('United Parcel Service', '989319-447', Decimal('3689.99')),
#  ('United Parcel Service', '989319-417', Decimal('2051.59')),
#  ('United Parcel Service', '989319-467', Decimal('2318.03')),
#  ('United Parcel Service', '989319-487', Decimal('1927.54')),
#  ('United Parcel Service', '989319-427', Decimal('2115.81')),
#  ('United Parcel Service', '989319-497', Decimal('2312.20')),
#  ('United Parcel Service', '989319-477', Decimal('2184.11')),
#  ('United Parcel Service', '989319-437', Decimal('2765.36')),
#  ('Yesmed, Inc', '10843', Decimal('4901.26')),
#  ('Zylka Design', '97/522', Decimal('1962.13'))]

# %%
# %%sql # Get invoices smaller than the largest invoice for vendor 115
#
# SELECT vendor_name, invoice_number, invoice_total
# FROM Vendors v
#   JOIN Invoices i ON i.vendor_id = v.vendor_id
# WHERE invoice_total < ANY (
#   SELECT invoice_total
#   FROM Invoices
#   WHERE vendor_id = 115)
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 17 rows affected.
# [('Federal Express Corporation', '963253251', Decimal('15.50')),
#  ('Pacific Bell', '111-92R-10096', Decimal('16.33')),
#  ('Roadway Package System, Inc', '25022117', Decimal('6.00')),
#  ('Compuserve', '21-4748363', Decimal('9.95')),
#  ('Federal Express Corporation', '4-321-2596', Decimal('10.00')),
#  ('Roadway Package System, Inc', '24863706', Decimal('6.00')),
#  ('Compuserve', '21-4923721', Decimal('9.95')),
#  ('Federal Express Corporation', '4-342-8069', Decimal('10.00')),
#  ('Pacific Bell', '111-92R-10094', Decimal('19.67')),
#  ('Pacific Bell', '111-92R-10097', Decimal('16.33')),
#  ('Federal Express Corporation', '4-314-3057', Decimal('13.75')),
#  ('Federal Express Corporation', '963253267', Decimal('23.50')),
#  ('Roadway Package System, Inc', '24780512', Decimal('6.00')),
#  ('Federal Express Corporation', '43966316', Decimal('10.00')),
#  ('Abbey Office Furnishings', '203339-13', Decimal('17.50')),
#  ('Suburban Propane', '111897', Decimal('16.62')),
#  ('Federal Express Corporation', '263253257', Decimal('22.57'))]

# %%
# %%sql # same result with SOME keyword
#
# SELECT vendor_name, invoice_number, invoice_total
# FROM Vendors v
#   JOIN Invoices i ON i.vendor_id = v.vendor_id
# WHERE invoice_total < SOME (
#   SELECT invoice_total
#   FROM Invoices
#   WHERE vendor_id = 115)
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 17 rows affected.
# [('Federal Express Corporation', '963253251', Decimal('15.50')),
#  ('Pacific Bell', '111-92R-10096', Decimal('16.33')),
#  ('Roadway Package System, Inc', '25022117', Decimal('6.00')),
#  ('Compuserve', '21-4748363', Decimal('9.95')),
#  ('Federal Express Corporation', '4-321-2596', Decimal('10.00')),
#  ('Roadway Package System, Inc', '24863706', Decimal('6.00')),
#  ('Compuserve', '21-4923721', Decimal('9.95')),
#  ('Federal Express Corporation', '4-342-8069', Decimal('10.00')),
#  ('Pacific Bell', '111-92R-10094', Decimal('19.67')),
#  ('Pacific Bell', '111-92R-10097', Decimal('16.33')),
#  ('Federal Express Corporation', '4-314-3057', Decimal('13.75')),
#  ('Federal Express Corporation', '963253267', Decimal('23.50')),
#  ('Roadway Package System, Inc', '24780512', Decimal('6.00')),
#  ('Federal Express Corporation', '43966316', Decimal('10.00')),
#  ('Abbey Office Furnishings', '203339-13', Decimal('17.50')),
#  ('Suburban Propane', '111897', Decimal('16.62')),
#  ('Federal Express Corporation', '263253257', Decimal('22.57'))]

# %%
# %%sql # Get each invoice amount that's higher than the vendor's average invoice amount
#
# SELECT vendor_id, invoice_number, invoice_total
# FROM Invoices i
# WHERE invoice_total > (
#   SELECT AVG(invoice_total)
#   FROM Invoices
#   WHERE vendor_id = i.vendor_id)
# ORDER BY vendor_id, invoice_total;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 39 rows affected.
# [(34, 'Q545443', Decimal('1083.58')),
#  (37, '547480102', Decimal('224.00')),
#  (37, '547481328', Decimal('224.00')),
#  (72, '40318', Decimal('21842.00')),
#  (80, '133560', Decimal('175.00')),
#  (83, '31359783', Decimal('1575.00')),
#  (95, '111-92R-10095', Decimal('32.70')),
#  (95, '111-92R-10093', Decimal('39.77')),
#  (95, '111-92R-10092', Decimal('46.21')),
#  (97, '456791', Decimal('4390.00')),
#  (97, '456789', Decimal('8344.50')),
#  (97, '456789', Decimal('8344.50')),
#  (110, 'P-0259', Decimal('26881.40')),
#  (110, '0-2058', Decimal('37966.19')),
#  (115, '24946731', Decimal('25.67')),
#  (121, '97/553', Decimal('904.14')),
#  (121, '97/486', Decimal('953.10')),
#  (121, '97/222', Decimal('1000.46')),
#  (121, '97/522', Decimal('1962.13')),
#  (122, '989319-437', Decimal('2765.36')),
#  (122, '989319-447', Decimal('3689.99')),
#  (122, '989319-457', Decimal('3813.33')),
#  (123, '963253242', Decimal('104.00')),
#  (123, '963253235', Decimal('108.25')),
#  (123, '963253254', Decimal('108.50')),
#  (123, '963253263', Decimal('109.50')),
#  (123, '963253258', Decimal('111.00')),
#  (123, '963253232', Decimal('127.75')),
#  (123, '963253249', Decimal('127.75')),
#  (123, '963253246', Decimal('129.00')),
#  (123, '963253234', Decimal('138.75')),
#  (123, '2-000-2993', Decimal('144.70')),
#  (123, '963253239', Decimal('147.25')),
#  (123, '963253271', Decimal('158.00')),
#  (123, '4-327-7357', Decimal('162.75')),
#  (123, '963253237', Decimal('172.50')),
#  (123, '963253248', Decimal('241.00')),
#  (123, '94007069', Decimal('400.00')),
#  (123, '963253230', Decimal('739.20'))]

# %%
# %%sql # Get all vendors that don't have invoices
#
# SELECT vendor_id, vendor_name, vendor_state
# FROM Vendors v
# WHERE NOT EXISTS (
#   SELECT *
#   FROM Invoices
#   WHERE vendor_id = v.vendor_id)
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 88 rows affected.
# [(1, 'US Postal Service', 'WI'),
#  (2, 'National Information Data Ctr', 'DC'),
#  (3, 'Register of Copyrights', 'DC'),
#  (4, 'Jobtrak', 'CA'),
#  (5, 'Newbrige Book Clubs', 'NJ'),
#  (6, 'California Chamber Of Commerce', 'CA'),
#  (7, "Towne Advertiser's Mailing Svcs", 'CA'),
#  (8, 'BFI Industries', 'CA'),
#  (9, 'Pacific Gas & Electric', 'CA'),
#  (10, 'Robbins Mobile Lock And Key', 'CA'),
#  (11, 'Bill Marvin Electric Inc', 'CA'),
#  (12, 'City Of Fresno', 'CA'),
#  (13, 'Golden Eagle Insurance Co', 'CA'),
#  (14, 'Expedata Inc', 'CA'),
#  (15, 'ASC Signs', 'CA'),
#  (16, 'Internal Revenue Service', 'CA'),
#  (17, 'Blanchard & Johnson Associates', 'CA'),
#  (18, 'Fresno Photoengraving Company', 'CA'),
#  (19, 'Crown Printing', 'CA'),
#  (20, 'Diversified Printing & Pub', 'CA'),
#  (21, 'The Library Ltd', 'MO'),
#  (22, 'Micro Center', 'OH'),
#  (23, 'Yale Industrial Trucks-Fresno', 'CA'),
#  (24, 'Zee Medical Service Co', 'IA'),
#  (25, 'California Data Marketing', 'CA'),
#  (26, 'Small Press', 'MI'),
#  (27, 'Rich Advertising', 'NJ'),
#  (29, 'Vision Envelope & Printing', 'CA'),
#  (30, 'Costco', 'CA'),
#  (31, 'Enterprise Communications Inc', 'VA'),
#  (32, 'RR Bowker', 'NJ'),
#  (33, 'Nielson', 'OH'),
#  (35, 'Cal State Termite', 'CA'),
#  (36, 'Graylift', 'CA'),
#  (38, "Venture Communications Int'l", 'NY'),
#  (39, 'Custom Printing Company', 'MO'),
#  (40, 'Nat Assoc of College Stores', 'OH'),
#  (41, 'Shields Design', 'CA'),
#  (42, 'Opamp Technical Books', 'CA'),
#  (43, 'Capital Resource Credit', 'MN'),
#  (44, 'Courier Companies, Inc', 'MA'),
#  (45, 'Naylor Publications Inc', 'FL'),
#  (46, 'Open Horizons Publishing', 'IA'),
#  (47, 'Baker & Taylor Books', 'NC'),
#  (49, 'Mcgraw Hill Companies', 'IL'),
#  (50, 'Publishers Weekly', 'OH'),
#  (51, 'Blue Shield of California', 'CA'),
#  (52, 'Aztek Label', 'CA'),
#  (53, 'Gary McKeighan Insurance', 'CA'),
#  (54, 'Ph Photographic Services', 'CA'),
#  (55, 'Quality Education Data', 'IL'),
#  (56, 'Springhouse Corp', 'PA'),
#  (57, 'The Windows Deck', 'CA'),
#  (58, 'Fresno Rack & Shelving Inc', 'CA'),
#  (59, 'Publishers Marketing Assoc', 'CA'),
#  (60, 'The Mailers Guide Co', 'NY'),
#  (61, 'American Booksellers Assoc', 'NY'),
#  (62, 'Cmg Information Services', 'MA'),
#  (63, "Lou Gentile's Flower Basket", 'CA'),
#  (64, 'Texaco', 'CA'),
#  (65, 'The Drawing Board', 'IL'),
#  (66, 'Ascom Hasler Mailing Systems', 'CT'),
#  (67, 'Bill Jones', 'CA'),
#  (68, 'Computer Library', 'AZ'),
#  (69, 'Frank E Wilber Co', 'CA'),
#  (70, 'Fresno Credit Bureau', 'CA'),
#  (71, 'The Fresno Bee', 'CA'),
#  (73, 'Executive Office Products', 'CA'),
#  (74, 'Leslie Company', 'KS'),
#  (75, 'Retirement Plan Consultants', 'CA'),
#  (76, 'Simon Direct Inc', 'NJ'),
#  (77, 'State Board Of Equalization', 'CA'),
#  (78, 'The Presort Center', 'CA'),
#  (79, 'Valprint', 'CA'),
#  (84, 'Boucher Communications Inc', 'PA'),
#  (85, 'Champion Printing Company', 'OH'),
#  (87, 'DMV Renewal', 'CA'),
#  (91, 'McKesson Water Products', 'CA'),
#  (92, 'Zip Print & Copy Center', 'CA'),
#  (93, 'AT&T', 'AZ'),
#  (98, 'American Express', 'CA'),
#  (101, 'California Business Machines', 'CA'),
#  (109, 'Kent H Landsberg Co', 'CA'),
#  (111, 'Net Asset, Llc', 'CA'),
#  (112, 'Office Depot', 'CA'),
#  (116, 'State of California', 'CA'),
#  (118, 'Unocal', 'CA'),
#  (120, 'Dataforms/West', 'CA')]

# %% [markdown]
# ### Subqueries in other clauses (Select and From)

# %%
# %%sql # Get most recent invoice date for each vendor
#
# SELECT vendor_name,
#   (SELECT MAX(invoice_date) FROM Invoices
#     WHERE vendor_id = v.vendor_id) AS latest_inv
# FROM Vendors v
# ORDER BY latest_inv DESC;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 122 rows affected.
# [('Compuserve', datetime.date(2018, 8, 3)),
#  ('Federal Express Corporation', datetime.date(2018, 8, 2)),
#  ('Blue Cross', datetime.date(2018, 8, 1)),
#  ('Malloy Lithographing Inc', datetime.date(2018, 7, 31)),
#  ('Cardinal Business Media, Inc.', datetime.date(2018, 7, 28)),
#  ('Zylka Design', datetime.date(2018, 7, 25)),
#  ('Ford Motor Credit Company', datetime.date(2018, 7, 24)),
#  ('United Parcel Service', datetime.date(2018, 7, 24)),
#  ('Ingram', datetime.date(2018, 7, 21)),
#  ('Wakefield Co', datetime.date(2018, 7, 20)),
#  ("Reiter's Scientific & Pro Books", datetime.date(2018, 7, 19)),
#  ('Pacific Bell', datetime.date(2018, 7, 15)),
#  ('Suburban Propane', datetime.date(2018, 7, 15)),
#  ('Data Reproductions Corp', datetime.date(2018, 7, 10)),
#  ('Abbey Office Furnishings', datetime.date(2018, 7, 5)),
#  ('Cahners Publishing Company', datetime.date(2018, 6, 30)),
#  ('Coffee Break Service', datetime.date(2018, 6, 24)),
#  ('Postmaster', datetime.date(2018, 6, 23)),
#  ('Roadway Package System, Inc', datetime.date(2018, 6, 22)),
#  ('Wang Laboratories, Inc.', datetime.date(2018, 6, 21)),
#  ('Bertelsmann Industry Svcs. Inc', datetime.date(2018, 6, 18)),
#  ('Computerworld', datetime.date(2018, 6, 11)),
#  ('Dean Witter Reynolds', datetime.date(2018, 6, 11)),
#  ('IBM', datetime.date(2018, 6, 9)),
#  ('Franchise Tax Board', datetime.date(2018, 5, 25)),
#  ('Dristas Groom & McCormick', datetime.date(2018, 5, 23)),
#  ('Digital Dreamworks', datetime.date(2018, 5, 21)),
#  ('Gostanian General Building', datetime.date(2018, 5, 19)),
#  ('Edward Data Services', datetime.date(2018, 5, 15)),
#  ('Pollstar', datetime.date(2018, 5, 13)),
#  ('Yesmed, Inc', datetime.date(2018, 5, 11)),
#  ('Fresno County Tax Collector', datetime.date(2018, 5, 3)),
#  ('Wells Fargo Bank', datetime.date(2018, 4, 26)),
#  ('Evans Executone Inc', datetime.date(2018, 4, 24)),
#  ('American Booksellers Assoc', None),
#  ('American Express', None),
#  ('ASC Signs', None),
#  ('Ascom Hasler Mailing Systems', None),
#  ('AT&T', None),
#  ('Aztek Label', None),
#  ('Baker & Taylor Books', None),
#  ('BFI Industries', None),
#  ('Bill Jones', None),
#  ('Bill Marvin Electric Inc', None),
#  ('Blanchard & Johnson Associates', None),
#  ('Blue Shield of California', None),
#  ('Boucher Communications Inc', None),
#  ('Cal State Termite', None),
#  ('California Business Machines', None),
#  ('California Chamber Of Commerce', None),
#  ('California Data Marketing', None),
#  ('Capital Resource Credit', None),
#  ('Champion Printing Company', None),
#  ('City Of Fresno', None),
#  ('Cmg Information Services', None),
#  ('Computer Library', None),
#  ('Costco', None),
#  ('Courier Companies, Inc', None),
#  ('Crown Printing', None),
#  ('Custom Printing Company', None),
#  ('Dataforms/West', None),
#  ('Diversified Printing & Pub', None),
#  ('DMV Renewal', None),
#  ('Enterprise Communications Inc', None),
#  ('Executive Office Products', None),
#  ('Expedata Inc', None),
#  ('Frank E Wilber Co', None),
#  ('Fresno Credit Bureau', None),
#  ('Fresno Photoengraving Company', None),
#  ('Fresno Rack & Shelving Inc', None),
#  ('Gary McKeighan Insurance', None),
#  ('Golden Eagle Insurance Co', None),
#  ('Graylift', None),
#  ('Internal Revenue Service', None),
#  ('Jobtrak', None),
#  ('Kent H Landsberg Co', None),
#  ('Leslie Company', None),
#  ("Lou Gentile's Flower Basket", None),
#  ('Mcgraw Hill Companies', None),
#  ('McKesson Water Products', None),
#  ('Micro Center', None),
#  ('Nat Assoc of College Stores', None),
#  ('National Information Data Ctr', None),
#  ('Naylor Publications Inc', None),
#  ('Net Asset, Llc', None),
#  ('Newbrige Book Clubs', None),
#  ('Nielson', None),
#  ('Office Depot', None),
#  ('Opamp Technical Books', None),
#  ('Open Horizons Publishing', None),
#  ('Pacific Gas & Electric', None),
#  ('Ph Photographic Services', None),
#  ('Publishers Marketing Assoc', None),
#  ('Publishers Weekly', None),
#  ('Quality Education Data', None),
#  ('Register of Copyrights', None),
#  ('Retirement Plan Consultants', None),
#  ('Rich Advertising', None),
#  ('Robbins Mobile Lock And Key', None),
#  ('RR Bowker', None),
#  ('Shields Design', None),
#  ('Simon Direct Inc', None),
#  ('Small Press', None),
#  ('Springhouse Corp', None),
#  ('State Board Of Equalization', None),
#  ('State of California', None),
#  ('Texaco', None),
#  ('The Drawing Board', None),
#  ('The Fresno Bee', None),
#  ('The Library Ltd', None),
#  ('The Mailers Guide Co', None),
#  ('The Presort Center', None),
#  ('The Windows Deck', None),
#  ("Towne Advertiser's Mailing Svcs", None),
#  ('Unocal', None),
#  ('US Postal Service', None),
#  ('Valprint', None),
#  ("Venture Communications Int'l", None),
#  ('Vision Envelope & Printing', None),
#  ('Yale Industrial Trucks-Fresno', None),
#  ('Zee Medical Service Co', None),
#  ('Zip Print & Copy Center', None)]

# %%
# %%sql # Same query restated using a join
#
# SELECT vendor_name, MAX(invoice_date) AS latest_inv
# FROM Vendors v
#   LEFT JOIN Invoices i ON v.vendor_id = i.vendor_id
# GROUP BY vendor_name
# ORDER BY latest_inv DESC;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 122 rows affected.
# [('Compuserve', datetime.date(2018, 8, 3)),
#  ('Federal Express Corporation', datetime.date(2018, 8, 2)),
#  ('Blue Cross', datetime.date(2018, 8, 1)),
#  ('Malloy Lithographing Inc', datetime.date(2018, 7, 31)),
#  ('Cardinal Business Media, Inc.', datetime.date(2018, 7, 28)),
#  ('Zylka Design', datetime.date(2018, 7, 25)),
#  ('Ford Motor Credit Company', datetime.date(2018, 7, 24)),
#  ('United Parcel Service', datetime.date(2018, 7, 24)),
#  ('Ingram', datetime.date(2018, 7, 21)),
#  ('Wakefield Co', datetime.date(2018, 7, 20)),
#  ("Reiter's Scientific & Pro Books", datetime.date(2018, 7, 19)),
#  ('Pacific Bell', datetime.date(2018, 7, 15)),
#  ('Suburban Propane', datetime.date(2018, 7, 15)),
#  ('Data Reproductions Corp', datetime.date(2018, 7, 10)),
#  ('Abbey Office Furnishings', datetime.date(2018, 7, 5)),
#  ('Cahners Publishing Company', datetime.date(2018, 6, 30)),
#  ('Coffee Break Service', datetime.date(2018, 6, 24)),
#  ('Postmaster', datetime.date(2018, 6, 23)),
#  ('Roadway Package System, Inc', datetime.date(2018, 6, 22)),
#  ('Wang Laboratories, Inc.', datetime.date(2018, 6, 21)),
#  ('Bertelsmann Industry Svcs. Inc', datetime.date(2018, 6, 18)),
#  ('Computerworld', datetime.date(2018, 6, 11)),
#  ('Dean Witter Reynolds', datetime.date(2018, 6, 11)),
#  ('IBM', datetime.date(2018, 6, 9)),
#  ('Franchise Tax Board', datetime.date(2018, 5, 25)),
#  ('Dristas Groom & McCormick', datetime.date(2018, 5, 23)),
#  ('Digital Dreamworks', datetime.date(2018, 5, 21)),
#  ('Gostanian General Building', datetime.date(2018, 5, 19)),
#  ('Edward Data Services', datetime.date(2018, 5, 15)),
#  ('Pollstar', datetime.date(2018, 5, 13)),
#  ('Yesmed, Inc', datetime.date(2018, 5, 11)),
#  ('Fresno County Tax Collector', datetime.date(2018, 5, 3)),
#  ('Wells Fargo Bank', datetime.date(2018, 4, 26)),
#  ('Evans Executone Inc', datetime.date(2018, 4, 24)),
#  ('American Booksellers Assoc', None),
#  ('American Express', None),
#  ('ASC Signs', None),
#  ('Ascom Hasler Mailing Systems', None),
#  ('AT&T', None),
#  ('Aztek Label', None),
#  ('Baker & Taylor Books', None),
#  ('BFI Industries', None),
#  ('Bill Jones', None),
#  ('Bill Marvin Electric Inc', None),
#  ('Blanchard & Johnson Associates', None),
#  ('Blue Shield of California', None),
#  ('Boucher Communications Inc', None),
#  ('Cal State Termite', None),
#  ('California Business Machines', None),
#  ('California Chamber Of Commerce', None),
#  ('California Data Marketing', None),
#  ('Capital Resource Credit', None),
#  ('Champion Printing Company', None),
#  ('City Of Fresno', None),
#  ('Cmg Information Services', None),
#  ('Computer Library', None),
#  ('Costco', None),
#  ('Courier Companies, Inc', None),
#  ('Crown Printing', None),
#  ('Custom Printing Company', None),
#  ('Dataforms/West', None),
#  ('Diversified Printing & Pub', None),
#  ('DMV Renewal', None),
#  ('Enterprise Communications Inc', None),
#  ('Executive Office Products', None),
#  ('Expedata Inc', None),
#  ('Frank E Wilber Co', None),
#  ('Fresno Credit Bureau', None),
#  ('Fresno Photoengraving Company', None),
#  ('Fresno Rack & Shelving Inc', None),
#  ('Gary McKeighan Insurance', None),
#  ('Golden Eagle Insurance Co', None),
#  ('Graylift', None),
#  ('Internal Revenue Service', None),
#  ('Jobtrak', None),
#  ('Kent H Landsberg Co', None),
#  ('Leslie Company', None),
#  ("Lou Gentile's Flower Basket", None),
#  ('Mcgraw Hill Companies', None),
#  ('McKesson Water Products', None),
#  ('Micro Center', None),
#  ('Nat Assoc of College Stores', None),
#  ('National Information Data Ctr', None),
#  ('Naylor Publications Inc', None),
#  ('Net Asset, Llc', None),
#  ('Newbrige Book Clubs', None),
#  ('Nielson', None),
#  ('Office Depot', None),
#  ('Opamp Technical Books', None),
#  ('Open Horizons Publishing', None),
#  ('Pacific Gas & Electric', None),
#  ('Ph Photographic Services', None),
#  ('Publishers Marketing Assoc', None),
#  ('Publishers Weekly', None),
#  ('Quality Education Data', None),
#  ('Register of Copyrights', None),
#  ('Retirement Plan Consultants', None),
#  ('Rich Advertising', None),
#  ('Robbins Mobile Lock And Key', None),
#  ('RR Bowker', None),
#  ('Shields Design', None),
#  ('Simon Direct Inc', None),
#  ('Small Press', None),
#  ('Springhouse Corp', None),
#  ('State Board Of Equalization', None),
#  ('State of California', None),
#  ('Texaco', None),
#  ('The Drawing Board', None),
#  ('The Fresno Bee', None),
#  ('The Library Ltd', None),
#  ('The Mailers Guide Co', None),
#  ('The Presort Center', None),
#  ('The Windows Deck', None),
#  ("Towne Advertiser's Mailing Svcs", None),
#  ('Unocal', None),
#  ('US Postal Service', None),
#  ('Valprint', None),
#  ("Venture Communications Int'l", None),
#  ('Vision Envelope & Printing', None),
#  ('Yale Industrial Trucks-Fresno', None),
#  ('Zee Medical Service Co', None),
#  ('Zip Print & Copy Center', None)]

# %%
# %%sql # Get the largest invoice total for the top vendor in each state
#
# SELECT vendor_state, MAX(sum_of_invoices) AS max_sum_inv
# FROM (
#   SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
#   FROM Vendors v
#     JOIN Invoices i ON v.vendor_id = i.vendor_id
#   GROUP BY vendor_state, vendor_name) t
# GROUP BY vendor_state
# ORDER BY vendor_state;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 10 rows affected.
# [('AZ', Decimal('662.00')),
#  ('CA', Decimal('7125.34')),
#  ('DC', Decimal('600.00')),
#  ('MA', Decimal('1367.50')),
#  ('MI', Decimal('119892.41')),
#  ('NV', Decimal('23177.96')),
#  ('OH', Decimal('21935.00')),
#  ('PA', Decimal('265.36')),
#  ('TN', Decimal('4378.02')),
#  ('TX', Decimal('2154.42'))]

# %%
# %%sql # Result of the subquery (an inline view)
#
# SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
# FROM Vendors v
#   JOIN Invoices i ON i.vendor_id = v.vendor_id
# GROUP BY vendor_state, vendor_name
# ORDER BY vendor_state;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 34 rows affected.
# [('AZ', 'Wells Fargo Bank', Decimal('662.00')),
#  ('CA', 'Abbey Office Furnishings', Decimal('17.50')),
#  ('CA', 'Bertelsmann Industry Svcs. Inc', Decimal('6940.25')),
#  ('CA', 'Blue Cross', Decimal('564.00')),
#  ('CA', 'Coffee Break Service', Decimal('41.80')),
#  ('CA', 'Computerworld', Decimal('2433.00')),
#  ('CA', 'Digital Dreamworks', Decimal('7125.34')),
#  ('CA', 'Dristas Groom & McCormick', Decimal('220.00')),
#  ('CA', 'Evans Executone Inc', Decimal('95.00')),
#  ('CA', 'Ford Motor Credit Company', Decimal('503.20')),
#  ('CA', 'Franchise Tax Board', Decimal('1600.00')),
#  ('CA', 'Fresno County Tax Collector', Decimal('856.92')),
#  ('CA', 'Gostanian General Building', Decimal('450.00')),
#  ('CA', 'IBM', Decimal('1200.12')),
#  ('CA', 'Pacific Bell', Decimal('171.01')),
#  ('CA', 'Pollstar', Decimal('1750.00')),
#  ('CA', 'Postmaster', Decimal('290.00')),
#  ('CA', 'Roadway Package System, Inc', Decimal('43.67')),
#  ('CA', 'Suburban Propane', Decimal('16.62')),
#  ('CA', 'Wakefield Co', Decimal('356.48')),
#  ('CA', 'Wang Laboratories, Inc.', Decimal('936.93')),
#  ('CA', 'Yesmed, Inc', Decimal('4901.26')),
#  ('CA', 'Zylka Design', Decimal('6940.25')),
#  ('DC', "Reiter's Scientific & Pro Books", Decimal('600.00')),
#  ('MA', 'Dean Witter Reynolds', Decimal('1367.50')),
#  ('MI', 'Data Reproductions Corp', Decimal('21927.31')),
#  ('MI', 'Malloy Lithographing Inc', Decimal('119892.41')),
#  ('NV', 'Cahners Publishing Company', Decimal('2184.50')),
#  ('NV', 'United Parcel Service', Decimal('23177.96')),
#  ('OH', 'Compuserve', Decimal('21935.00')),
#  ('OH', 'Edward Data Services', Decimal('207.78')),
#  ('PA', 'Cardinal Business Media, Inc.', Decimal('265.36')),
#  ('TN', 'Federal Express Corporation', Decimal('4378.02')),
#  ('TX', 'Ingram', Decimal('2154.42'))]

# %% [markdown]
# ### Work with complex queries

# %%
# %%sql # a complex query that uses three subqueries,
#       # Which vendor in each state has the largest invoice total ?
#
# SELECT t1.vendor_state, vendor_name, t1.sum_of_invoices
# FROM (
#   SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
#   FROM Vendors v
#     JOIN Invoices i ON i.vendor_id = v.vendor_id
#   GROUP BY vendor_state, vendor_name) t1
#     JOIN (
#       SELECT vendor_state, MAX(sum_of_invoices) AS sum_of_invoices
#       FROM (
#         SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
#         FROM Vendors v
#           JOIN Invoices i ON v.vendor_id = i.vendor_id
#         GROUP BY vendor_state, vendor_name) t2
#       GROUP BY vendor_state) t3
#   ON t1.vendor_state = t3.vendor_state AND t1.sum_of_invoices = t3.sum_of_invoices
# ORDER BY vendor_state
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 10 rows affected.
# [('AZ', 'Wells Fargo Bank', Decimal('662.00')),
#  ('CA', 'Digital Dreamworks', Decimal('7125.34')),
#  ('DC', "Reiter's Scientific & Pro Books", Decimal('600.00')),
#  ('MA', 'Dean Witter Reynolds', Decimal('1367.50')),
#  ('MI', 'Malloy Lithographing Inc', Decimal('119892.41')),
#  ('NV', 'United Parcel Service', Decimal('23177.96')),
#  ('OH', 'Compuserve', Decimal('21935.00')),
#  ('PA', 'Cardinal Business Media, Inc.', Decimal('265.36')),
#  ('TN', 'Federal Express Corporation', Decimal('4378.02')),
#  ('TX', 'Ingram', Decimal('2154.42'))]

# %%
# %%sql # code for the first subquery
#
# SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
# FROM Vendors v
#   JOIN Invoices i ON v.vendor_id = i.vendor_id
# GROUP BY vendor_state, vendor_name;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 34 rows affected.
# [('NV', 'United Parcel Service', Decimal('23177.96')),
#  ('TN', 'Federal Express Corporation', Decimal('4378.02')),
#  ('CA', 'Evans Executone Inc', Decimal('95.00')),
#  ('CA', 'Zylka Design', Decimal('6940.25')),
#  ('AZ', 'Wells Fargo Bank', Decimal('662.00')),
#  ('CA', 'Pacific Bell', Decimal('171.01')),
#  ('CA', 'Roadway Package System, Inc', Decimal('43.67')),
#  ('CA', 'Fresno County Tax Collector', Decimal('856.92')),
#  ('OH', 'Compuserve', Decimal('21935.00')),
#  ('CA', 'IBM', Decimal('1200.12')),
#  ('CA', 'Yesmed, Inc', Decimal('4901.26')),
#  ('CA', 'Pollstar', Decimal('1750.00')),
#  ('OH', 'Edward Data Services', Decimal('207.78')),
#  ('CA', 'Gostanian General Building', Decimal('450.00')),
#  ('CA', 'Digital Dreamworks', Decimal('7125.34')),
#  ('CA', 'Dristas Groom & McCormick', Decimal('220.00')),
#  ('CA', 'Franchise Tax Board', Decimal('1600.00')),
#  ('MI', 'Malloy Lithographing Inc', Decimal('119892.41')),
#  ('MI', 'Data Reproductions Corp', Decimal('21927.31')),
#  ('CA', 'Blue Cross', Decimal('564.00')),
#  ('TX', 'Ingram', Decimal('2154.42')),
#  ('CA', 'Computerworld', Decimal('2433.00')),
#  ('MA', 'Dean Witter Reynolds', Decimal('1367.50')),
#  ('CA', 'Bertelsmann Industry Svcs. Inc', Decimal('6940.25')),
#  ('CA', 'Wang Laboratories, Inc.', Decimal('936.93')),
#  ('PA', 'Cardinal Business Media, Inc.', Decimal('265.36')),
#  ('CA', 'Postmaster', Decimal('290.00')),
#  ('CA', 'Coffee Break Service', Decimal('41.80')),
#  ('NV', 'Cahners Publishing Company', Decimal('2184.50')),
#  ('CA', 'Abbey Office Furnishings', Decimal('17.50')),
#  ('CA', 'Suburban Propane', Decimal('16.62')),
#  ('DC', "Reiter's Scientific & Pro Books", Decimal('600.00')),
#  ('CA', 'Wakefield Co', Decimal('356.48')),
#  ('CA', 'Ford Motor Credit Company', Decimal('503.20'))]

# %%
# %%sql # The code for the second subquery
#
# SELECT vendor_state, MAX(sum_of_invoices) AS sum_of_invoices
# FROM (
#   SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
#   FROM Vendors v
#     JOIN Invoices i ON v.vendor_id = i.vendor_id
#   GROUP BY vendor_state, vendor_name) t
# GROUP BY vendor_state;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 10 rows affected.
# [('NV', Decimal('23177.96')),
#  ('TN', Decimal('4378.02')),
#  ('CA', Decimal('7125.34')),
#  ('AZ', Decimal('662.00')),
#  ('OH', Decimal('21935.00')),
#  ('MI', Decimal('119892.41')),
#  ('TX', Decimal('2154.42')),
#  ('MA', Decimal('1367.50')),
#  ('PA', Decimal('265.36')),
#  ('DC', Decimal('600.00'))]

# %% [markdown]
# ### Work with common table expressions

# %%
# %%sql # The previous complex query rewrite with cte
#
# WITH summary AS (
#   SELECT vendor_state, vendor_name, SUM(invoice_total) AS sum_of_invoices
#   FROM Vendors v
#     JOIN Invoices i ON i.vendor_id = v.vendor_id
#   GROUP BY vendor_state, vendor_name),
# top_in_state AS (
#   SELECT vendor_state, MAX(sum_of_invoices) AS sum_of_invoices
#   FROM summary
#   GROUP BY vendor_state)
# SELECT s.vendor_state, s.vendor_name, t.sum_of_invoices
# FROM summary s JOIN top_in_state t
#   ON s.vendor_state = t.vendor_state AND s.sum_of_invoices = t.sum_of_invoices
# ORDER BY s.vendor_state;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 10 rows affected.
# [('AZ', 'Wells Fargo Bank', Decimal('662.00')),
#  ('CA', 'Digital Dreamworks', Decimal('7125.34')),
#  ('DC', "Reiter's Scientific & Pro Books", Decimal('600.00')),
#  ('MA', 'Dean Witter Reynolds', Decimal('1367.50')),
#  ('MI', 'Malloy Lithographing Inc', Decimal('119892.41')),
#  ('NV', 'United Parcel Service', Decimal('23177.96')),
#  ('OH', 'Compuserve', Decimal('21935.00')),
#  ('PA', 'Cardinal Business Media, Inc.', Decimal('265.36')),
#  ('TN', 'Federal Express Corporation', Decimal('4378.02')),
#  ('TX', 'Ingram', Decimal('2154.42'))]

# %% [markdown]
# ### Recursive CTE

# %%
# %sql USE ex;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 0 rows affected.
# []

# %%
# %sql SHOW TABLES;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 14 rows affected.
# [('Active_invoices',),
#  ('Color_sample',),
#  ('Customers',),
#  ('Date_sample',),
#  ('Departments',),
#  ('Employees',),
#  ('Engine_sample',),
#  ('Float_sample',),
#  ('Null_sample',),
#  ('Paid_invoices',),
#  ('Projects',),
#  ('Sales_reps',),
#  ('Sales_totals',),
#  ('String_sample',)]

# %%
# %sql SELECT * FROM Employees;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 9 rows affected.
# [(1, 'Smith', 'Cindy', 2, None),
#  (2, 'Jones', 'Elmer', 4, 1),
#  (3, 'Simonian', 'Ralph', 2, 2),
#  (4, 'Hernandez', 'Olivia', 1, 9),
#  (5, 'Aaronsen', 'Robert', 2, 4),
#  (6, 'Watson', 'Denise', 6, 8),
#  (7, 'Hardy', 'Thomas', 5, 2),
#  (8, "O'Leary", 'Rhea', 4, 9),
#  (9, 'Locario', 'Paulo', 6, 1)]

# %%
# %%sql # Recursive cte that returns hierarchical data
#
# WITH RECURSIVE employees_cte AS (
#   SELECT employee_id,
#     CONCAT(first_name, ' ', last_name) AS employee_name, 1 AS ranking
#   FROM Employees
#   WHERE manager_id is NULL
#   UNION
#   SELECT e.employee_id,
#     CONCAT(first_name, ' ', last_name), ranking + 1
#   FROM Employees e
#     JOIN employees_cte ON e.manager_id = employees_cte.employee_id)
# SELECT *
# FROM employees_cte
# ORDER BY ranking, employee_id;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 9 rows affected.
# [(1, 'Cindy Smith', 1),
#  (2, 'Elmer Jones', 2),
#  (9, 'Paulo Locario', 2),
#  (3, 'Ralph Simonian', 3),
#  (4, 'Olivia Hernandez', 3),
#  (7, 'Thomas Hardy', 3),
#  (8, "Rhea O'Leary", 3),
#  (5, 'Robert Aaronsen', 4),
#  (6, 'Denise Watson', 4)]

# %% [markdown]
# ### Extra

# %%
# %%sql # Select all with an invoices
#
# SELECT DISTINCT vendor_name
# FROM Vendors v
#   JOIN Invoices i ON i.vendor_id = v.vendor_id
# ORDER BY vendor_name
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 34 rows affected.
# [('Abbey Office Furnishings',),
#  ('Bertelsmann Industry Svcs. Inc',),
#  ('Blue Cross',),
#  ('Cahners Publishing Company',),
#  ('Cardinal Business Media, Inc.',),
#  ('Coffee Break Service',),
#  ('Compuserve',),
#  ('Computerworld',),
#  ('Data Reproductions Corp',),
#  ('Dean Witter Reynolds',),
#  ('Digital Dreamworks',),
#  ('Dristas Groom & McCormick',),
#  ('Edward Data Services',),
#  ('Evans Executone Inc',),
#  ('Federal Express Corporation',),
#  ('Ford Motor Credit Company',),
#  ('Franchise Tax Board',),
#  ('Fresno County Tax Collector',),
#  ('Gostanian General Building',),
#  ('IBM',),
#  ('Ingram',),
#  ('Malloy Lithographing Inc',),
#  ('Pacific Bell',),
#  ('Pollstar',),
#  ('Postmaster',),
#  ("Reiter's Scientific & Pro Books",),
#  ('Roadway Package System, Inc',),
#  ('Suburban Propane',),
#  ('United Parcel Service',),
#  ('Wakefield Co',),
#  ('Wang Laboratories, Inc.',),
#  ('Wells Fargo Bank',),
#  ('Yesmed, Inc',),
#  ('Zylka Design',)]

# %%
# %%sql #1 a statement that returns the same results set but don't use a join
#
# SELECT vendor_name
# FROM Vendors
# WHERE vendor_id IN (
#   SELECT DISTINCT vendor_id
#   FROM Invoices
# )
# ORDER BY vendor_name;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 34 rows affected.
# [('Abbey Office Furnishings',),
#  ('Bertelsmann Industry Svcs. Inc',),
#  ('Blue Cross',),
#  ('Cahners Publishing Company',),
#  ('Cardinal Business Media, Inc.',),
#  ('Coffee Break Service',),
#  ('Compuserve',),
#  ('Computerworld',),
#  ('Data Reproductions Corp',),
#  ('Dean Witter Reynolds',),
#  ('Digital Dreamworks',),
#  ('Dristas Groom & McCormick',),
#  ('Edward Data Services',),
#  ('Evans Executone Inc',),
#  ('Federal Express Corporation',),
#  ('Ford Motor Credit Company',),
#  ('Franchise Tax Board',),
#  ('Fresno County Tax Collector',),
#  ('Gostanian General Building',),
#  ('IBM',),
#  ('Ingram',),
#  ('Malloy Lithographing Inc',),
#  ('Pacific Bell',),
#  ('Pollstar',),
#  ('Postmaster',),
#  ("Reiter's Scientific & Pro Books",),
#  ('Roadway Package System, Inc',),
#  ('Suburban Propane',),
#  ('United Parcel Service',),
#  ('Wakefield Co',),
#  ('Wang Laboratories, Inc.',),
#  ('Wells Fargo Bank',),
#  ('Yesmed, Inc',),
#  ('Zylka Design',)]

# %%
# %%sql #2 Which invoices have a payment total that's greater than te average payment total for all invoices with a payment total greater than 0
#
# SELECT invoice_id, invoice_number, invoice_total
# FROM Invoices
# WHERE invoice_total > (
#   SELECT AVG(payment_total)
#   FROM Invoices
#   WHERE payment_total > 0
# )
# ORDER BY invoice_total DESC;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 24 rows affected.
# [(39, '0-2058', Decimal('37966.19')),
#  (96, 'P-0259', Decimal('26881.40')),
#  (106, '0-2060', Decimal('23517.58')),
#  (43, '40318', Decimal('21842.00')),
#  (102, 'P-0608', Decimal('20551.18')),
#  (112, '0-2436', Decimal('10976.06')),
#  (116, '456789', Decimal('8344.50')),
#  (115, '456789', Decimal('8344.50')),
#  (31, 'P02-3772', Decimal('7125.34')),
#  (65, '509786', Decimal('6940.25')),
#  (21, '10843', Decimal('4901.26')),
#  (118, '456791', Decimal('4390.00')),
#  (1, '989319-457', Decimal('3813.33')),
#  (107, '989319-447', Decimal('3689.99')),
#  (45, '989319-437', Decimal('2765.36')),
#  (56, '367447', Decimal('2433.00')),
#  (80, '989319-467', Decimal('2318.03')),
#  (60, '989319-497', Decimal('2312.20')),
#  (79, '587056', Decimal('2184.50')),
#  (51, '989319-477', Decimal('2184.11')),
#  (63, '989319-427', Decimal('2115.81')),
#  (103, '989319-417', Decimal('2051.59')),
#  (78, '97/522', Decimal('1962.13')),
#  (67, '989319-487', Decimal('1927.54'))]

# %%
# %%sql # The average payment total for all invoices with a payment total greater than 0
#
# SELECT AVG(payment_total) AS avg_invoices
# FROM Invoices
# WHERE payment_total > 0;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 1 rows affected.
# [(Decimal('1904.496990'),)]

# %%
# %sql SELECT * FROM General_ledger_accounts;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 74 rows affected.
# [(221, '401K Employee Contributions'),
#  (591, 'Accounting'),
#  (200, 'Accounts Payable'),
#  (110, 'Accounts Receivable'),
#  (569, 'Auto Expense'),
#  (568, 'Auto License Fee'),
#  (565, 'Bank Fees'),
#  (394, 'Book Club Royalties'),
#  (181, 'Book Development'),
#  (120, 'Book Inventory'),
#  (400, 'Book Printing Costs'),
#  (403, 'Book Production Costs'),
#  (572, 'Books, Dues, and Subscriptions'),
#  (520, 'Building Lease'),
#  (523, 'Building Maintenance'),
#  (551, 'Business Forms'),
#  (590, 'Business Insurance'),
#  (574, 'Business Licenses and Taxes'),
#  (280, 'Capital Stock'),
#  (162, 'Capitalized Lease'),
#  (536, 'Card Deck Advertising'),
#  (100, 'Cash'),
#  (610, 'Charitable Contributions'),
#  (555, 'Collection Agency Fees'),
#  (301, 'College Sales'),
#  (310, 'Compositing Revenue'),
#  (160, 'Computer Equipment'),
#  (527, 'Computer Equipment Maintenance'),
#  (556, 'Credit Card Handling'),
#  (540, 'Direct Mail Advertising'),
#  (238, 'Employee FICA Taxes Payable'),
#  (242, 'Employee SDI Taxes Payable'),
#  (239, 'Employer FICA Taxes Payable'),
#  (241, 'Employer FUTA Taxes Payable'),
#  (243, 'Employer UCI Taxes Payable'),
#  (532, 'Equipment Rental'),
#  (546, 'Exhibits and Shows'),
#  (630, 'Federal Corporation Income Taxes'),
#  (505, 'FICA'),
#  (553, 'Freight'),
#  (150, 'Furniture'),
#  (506, 'FUTA'),
#  (510, 'Group Insurance'),
#  (251, 'IBM Credit Corporation Payable'),
#  (528, 'IBM Lease'),
#  (235, 'Income Taxes Payable'),
#  (620, 'Interest Paid to Banks'),
#  (580, 'Meals'),
#  (508, 'Medicare'),
#  (234, 'Medicare Taxes Payable'),
#  (570, 'Office Supplies'),
#  (170, 'Other Equipment'),
#  (621, 'Other Interest'),
#  (589, 'Outside Services'),
#  (550, 'Packaging Materials'),
#  (576, 'PC Software'),
#  (552, 'Postage'),
#  (611, 'Profit Sharing Contributions'),
#  (300, 'Retail Sales'),
#  (290, 'Retained Earnings'),
#  (205, 'Royalties Payable'),
#  (500, 'Salaries and Wages'),
#  (632, 'Sales Tax'),
#  (230, 'Sales Taxes Payable'),
#  (167, 'Software'),
#  (541, 'Space Advertising'),
#  (631, 'State Corporation Income Taxes'),
#  (237, 'State Payroll Taxes Payable'),
#  (522, 'Telephone'),
#  (302, 'Trade Sales'),
#  (582, 'Travel and Accomodations'),
#  (507, 'UCI'),
#  (521, 'Utilities'),
#  (548, 'Web Site Production and Fees')]

# %%
# %sql SELECT * FROM Invoice_line_items;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 109 rows affected.
# [(1, 1, 553, Decimal('3813.33'), 'Freight'),
#  (2, 1, 553, Decimal('40.20'), 'Freight'),
#  (3, 1, 553, Decimal('138.75'), 'Freight'),
#  (4, 1, 553, Decimal('144.70'), "Int'l shipment"),
#  (5, 1, 553, Decimal('15.50'), 'Freight'),
#  (6, 1, 553, Decimal('42.75'), 'Freight'),
#  (7, 1, 553, Decimal('172.50'), 'Freight'),
#  (8, 1, 522, Decimal('95.00'), 'Telephone service'),
#  (9, 1, 403, Decimal('601.95'), 'Cover design'),
#  (10, 1, 553, Decimal('42.67'), 'Freight'),
#  (11, 1, 553, Decimal('42.50'), 'Freight'),
#  (13, 1, 522, Decimal('16.33'), 'Telephone (line 5)'),
#  (15, 1, 574, Decimal('856.92'), 'Property Taxes'),
#  (16, 1, 572, Decimal('9.95'), 'Monthly access fee'),
#  (17, 1, 553, Decimal('10.00'), 'Address correction'),
#  (18, 1, 553, Decimal('104.00'), 'Freight'),
#  (19, 1, 160, Decimal('116.54'), 'MVS Online Library'),
#  (21, 1, 589, Decimal('4901.26'), 'Office lease'),
#  (22, 1, 553, Decimal('108.25'), 'Freight'),
#  (23, 1, 572, Decimal('9.95'), 'Monthly access fee'),
#  (24, 1, 520, Decimal('1750.00'), 'Warehouse lease'),
#  (25, 1, 553, Decimal('129.00'), 'Freight'),
#  (26, 1, 553, Decimal('10.00'), 'Freight'),
#  (27, 1, 540, Decimal('207.78'), 'Prospect list'),
#  (28, 1, 553, Decimal('109.50'), 'Freight'),
#  (29, 1, 523, Decimal('450.00'), 'Back office additions'),
#  (30, 1, 553, Decimal('63.40'), 'Freight'),
#  (31, 1, 589, Decimal('7125.34'), 'Web site design'),
#  (32, 1, 403, Decimal('953.10'), 'Crash Course revision'),
#  (33, 1, 591, Decimal('220.00'), 'Form 571-L'),
#  (34, 1, 553, Decimal('127.75'), 'Freight'),
#  (35, 1, 507, Decimal('1600.00'), 'Income Tax'),
#  (36, 1, 403, Decimal('565.15'), 'Crash Course Ad'),
#  (37, 1, 553, Decimal('36.00'), 'Freight'),
#  (38, 1, 553, Decimal('61.50'), 'Freight'),
#  (39, 1, 400, Decimal('37966.19'), 'CICS Desk Reference'),
#  (40, 1, 403, Decimal('639.77'), 'Card deck'),
#  (41, 1, 553, Decimal('53.75'), 'Freight'),
#  (42, 1, 553, Decimal('400.00'), 'Freight'),
#  (43, 1, 400, Decimal('21842.00'), 'Book repro'),
#  (44, 1, 522, Decimal('19.67'), 'Telephone (Line 3)'),
#  (45, 1, 553, Decimal('2765.36'), 'Freight'),
#  (46, 1, 510, Decimal('224.00'), 'Health Insurance'),
#  (47, 1, 572, Decimal('1575.00'), 'Catalog ad'),
#  (48, 1, 553, Decimal('33.00'), 'Freight'),
#  (49, 1, 522, Decimal('16.33'), 'Telephone (line 6)'),
#  (50, 1, 510, Decimal('116.00'), 'Health Insurance'),
#  (51, 1, 553, Decimal('2184.11'), 'Freight'),
#  (52, 1, 160, Decimal('1083.58'), 'MSDN'),
#  (53, 1, 522, Decimal('46.21'), 'Telephone (Line 1)'),
#  (54, 1, 403, Decimal('313.55'), 'Card revision'),
#  (55, 1, 553, Decimal('40.75'), 'Freight'),
#  (56, 1, 572, Decimal('2433.00'), 'Card deck'),
#  (57, 1, 589, Decimal('1367.50'), '401K Contributions'),
#  (58, 1, 553, Decimal('53.25'), 'Freight'),
#  (59, 1, 553, Decimal('13.75'), 'Freight'),
#  (60, 1, 553, Decimal('2312.20'), 'Freight'),
#  (62, 1, 553, Decimal('26.75'), 'Freight'),
#  (63, 1, 553, Decimal('2115.81'), 'Freight'),
#  (64, 1, 553, Decimal('23.50'), 'Freight'),
#  (65, 1, 400, Decimal('6940.25'), 'OS Utilities'),
#  (66, 1, 553, Decimal('31.95'), 'Freight'),
#  (67, 1, 553, Decimal('1927.54'), 'Freight'),
#  (68, 1, 160, Decimal('936.93'), 'Quarterly Maintenance'),
#  (69, 1, 540, Decimal('175.00'), 'Card deck advertising'),
#  (71, 1, 553, Decimal('108.50'), 'Freight'),
#  (72, 1, 553, Decimal('10.00'), 'Address correction'),
#  (73, 1, 552, Decimal('290.00'), 'International pkg.'),
#  (74, 1, 570, Decimal('41.80'), 'Coffee'),
#  (75, 1, 553, Decimal('27.00'), 'Freight'),
#  (76, 1, 553, Decimal('241.00'), "Int'l shipment"),
#  (77, 1, 403, Decimal('904.14'), 'Cover design'),
#  (78, 1, 403, Decimal('1197.00'), 'Cover design'),
#  (79, 1, 540, Decimal('2184.50'), 'PC card deck'),
#  (80, 1, 553, Decimal('2318.03'), 'Freight'),
#  (81, 1, 553, Decimal('26.25'), 'Freight'),
#  (82, 1, 150, Decimal('17.50'), 'Supplies'),
#  (83, 1, 522, Decimal('39.77'), 'Telephone (Line 2)'),
#  (84, 1, 553, Decimal('111.00'), 'Freight'),
#  (85, 1, 553, Decimal('158.00'), "Int'l shipment"),
#  (86, 1, 553, Decimal('739.20'), 'Freight'),
#  (87, 1, 553, Decimal('60.00'), 'Freight'),
#  (88, 1, 553, Decimal('147.25'), 'Freight'),
#  (89, 1, 400, Decimal('85.31'), 'Book copy'),
#  (90, 1, 553, Decimal('38.75'), 'Freight'),
#  (91, 1, 522, Decimal('32.70'), 'Telephone (line 4)'),
#  (92, 1, 521, Decimal('16.62'), 'Propane-forklift'),
#  (93, 1, 553, Decimal('162.75'), 'International shipment'),
#  (94, 1, 553, Decimal('52.25'), 'Freight'),
#  (95, 1, 572, Decimal('600.00'), 'Books for research'),
#  (96, 1, 400, Decimal('26881.40'), 'MVS JCL'),
#  (97, 1, 170, Decimal('356.48'), 'Network wiring'),
#  (98, 1, 572, Decimal('579.42'), 'Catalog ad'),
#  (99, 1, 553, Decimal('59.97'), 'Freight'),
#  (100, 1, 553, Decimal('67.92'), 'Freight'),
#  (101, 1, 553, Decimal('30.75'), 'Freight'),
#  (102, 1, 400, Decimal('20551.18'), 'CICS book printing'),
#  (103, 1, 553, Decimal('2051.59'), 'Freight'),
#  (104, 1, 553, Decimal('44.44'), 'Freight'),
#  (105, 1, 582, Decimal('503.20'), 'Bronco lease'),
#  (106, 1, 400, Decimal('23517.58'), 'DB2 book printing'),
#  (107, 1, 553, Decimal('3689.99'), 'Freight'),
#  (108, 1, 553, Decimal('67.00'), 'Freight'),
#  (109, 1, 403, Decimal('1000.46'), 'Crash Course covers'),
#  (110, 1, 540, Decimal('90.36'), 'Card deck advertising'),
#  (111, 1, 553, Decimal('22.57'), 'Freight'),
#  (112, 1, 400, Decimal('10976.06'), 'VSAM book printing'),
#  (113, 1, 510, Decimal('224.00'), 'Health Insurance'),
#  (114, 1, 553, Decimal('127.75'), 'Freight')]

# %%
# %%sql #3 a select statement that returns one row for each account number that has never been assigned to any line item in Invoice line items table
#
# SELECT account_number, account_description
# FROM General_ledger_accounts ge
# WHERE NOT EXISTS (
#   SELECT account_number
#   FROM Invoice_line_items li
#   WHERE account_number = ge.account_number
# )
# ORDER BY account_number;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 54 rows affected.
# [(100, 'Cash'),
#  (110, 'Accounts Receivable'),
#  (120, 'Book Inventory'),
#  (162, 'Capitalized Lease'),
#  (167, 'Software'),
#  (181, 'Book Development'),
#  (200, 'Accounts Payable'),
#  (205, 'Royalties Payable'),
#  (221, '401K Employee Contributions'),
#  (230, 'Sales Taxes Payable'),
#  (234, 'Medicare Taxes Payable'),
#  (235, 'Income Taxes Payable'),
#  (237, 'State Payroll Taxes Payable'),
#  (238, 'Employee FICA Taxes Payable'),
#  (239, 'Employer FICA Taxes Payable'),
#  (241, 'Employer FUTA Taxes Payable'),
#  (242, 'Employee SDI Taxes Payable'),
#  (243, 'Employer UCI Taxes Payable'),
#  (251, 'IBM Credit Corporation Payable'),
#  (280, 'Capital Stock'),
#  (290, 'Retained Earnings'),
#  (300, 'Retail Sales'),
#  (301, 'College Sales'),
#  (302, 'Trade Sales'),
#  (310, 'Compositing Revenue'),
#  (394, 'Book Club Royalties'),
#  (500, 'Salaries and Wages'),
#  (505, 'FICA'),
#  (506, 'FUTA'),
#  (508, 'Medicare'),
#  (527, 'Computer Equipment Maintenance'),
#  (528, 'IBM Lease'),
#  (532, 'Equipment Rental'),
#  (536, 'Card Deck Advertising'),
#  (541, 'Space Advertising'),
#  (546, 'Exhibits and Shows'),
#  (548, 'Web Site Production and Fees'),
#  (550, 'Packaging Materials'),
#  (551, 'Business Forms'),
#  (555, 'Collection Agency Fees'),
#  (556, 'Credit Card Handling'),
#  (565, 'Bank Fees'),
#  (568, 'Auto License Fee'),
#  (569, 'Auto Expense'),
#  (576, 'PC Software'),
#  (580, 'Meals'),
#  (590, 'Business Insurance'),
#  (610, 'Charitable Contributions'),
#  (611, 'Profit Sharing Contributions'),
#  (620, 'Interest Paid to Banks'),
#  (621, 'Other Interest'),
#  (630, 'Federal Corporation Income Taxes'),
#  (631, 'State Corporation Income Taxes'),
#  (632, 'Sales Tax')]

# %%
# %sql SELECT * FROM Vendors;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 122 rows affected.
# [(1, 'US Postal Service', 'Attn:  Supt. Window Services', 'PO Box 7005', 'Madison', 'WI', '53707', '(800) 555-1205', 'Alberto', 'Francesco', 1, 552),
#  (2, 'National Information Data Ctr', 'PO Box 96621', None, 'Washington', 'DC', '20120', '(301) 555-8950', 'Irvin', 'Ania', 3, 540),
#  (3, 'Register of Copyrights', 'Library Of Congress', None, 'Washington', 'DC', '20559', None, 'Liana', 'Lukas', 3, 403),
#  (4, 'Jobtrak', '1990 Westwood Blvd Ste 260', None, 'Los Angeles', 'CA', '90025', '(800) 555-8725', 'Quinn', 'Kenzie', 3, 572),
#  (5, 'Newbrige Book Clubs', '3000 Cindel Drive', None, 'Washington', 'NJ', '07882', '(800) 555-9980', 'Marks', 'Michelle', 4, 394),
#  (6, 'California Chamber Of Commerce', '3255 Ramos Cir', None, 'Sacramento', 'CA', '95827', '(916) 555-6670', 'Mauro', 'Anton', 3, 572),
#  (7, "Towne Advertiser's Mailing Svcs", 'Kevin Minder', '3441 W Macarthur Blvd', 'Santa Ana', 'CA', '92704', None, 'Maegen', 'Ted', 3, 540),
#  (8, 'BFI Industries', 'PO Box 9369', None, 'Fresno', 'CA', '93792', '(559) 555-1551', 'Kaleigh', 'Erick', 3, 521),
#  (9, 'Pacific Gas & Electric', 'Box 52001', None, 'San Francisco', 'CA', '94152', '(800) 555-6081', 'Anthoni', 'Kaitlyn', 3, 521),
#  (10, 'Robbins Mobile Lock And Key', '4669 N Fresno', None, 'Fresno', 'CA', '93726', '(559) 555-9375', 'Leigh', 'Bill', 2, 523),
#  (11, 'Bill Marvin Electric Inc', '4583 E Home', None, 'Fresno', 'CA', '93703', '(559) 555-5106', 'Hostlery', 'Kaitlin', 2, 523),
#  (12, 'City Of Fresno', 'PO Box 2069', None, 'Fresno', 'CA', '93718', '(559) 555-9999', 'Mayte', 'Kendall', 3, 574),
#  (13, 'Golden Eagle Insurance Co', 'PO Box 85826', None, 'San Diego', 'CA', '92186', None, 'Blanca', 'Korah', 3, 590),
#  (14, 'Expedata Inc', '4420 N. First Street, Suite 108', None, 'Fresno', 'CA', '93726', '(559) 555-9586', 'Quintin', 'Marvin', 3, 589),
#  (15, 'ASC Signs', '1528 N Sierra Vista', None, 'Fresno', 'CA', '93703', None, 'Darien', 'Elisabeth', 1, 546),
#  (16, 'Internal Revenue Service', None, None, 'Fresno', 'CA', '93888', None, 'Aileen', 'Joan', 1, 235),
#  (17, 'Blanchard & Johnson Associates', '27371 Valderas', None, 'Mission Viejo', 'CA', '92691', '(214) 555-3647', 'Keeton', 'Gonzalo', 3, 540),
#  (18, 'Fresno Photoengraving Company', '1952 "H" Street', 'P.O. Box 1952', 'Fresno', 'CA', '93718', '(559) 555-3005', 'Chaddick', 'Derek', 3, 403),
#  (19, 'Crown Printing', '1730 "H" St', None, 'Fresno', 'CA', '93721', '(559) 555-7473', 'Randrup', 'Leann', 2, 400),
#  (20, 'Diversified Printing & Pub', '2632 Saturn St', None, 'Brea', 'CA', '92621', '(714) 555-4541', 'Lane', 'Vanesa', 3, 400),
#  (21, 'The Library Ltd', '7700 Forsyth', None, 'St Louis', 'MO', '63105', '(314) 555-8834', 'Marques', 'Malia', 3, 540),
#  (22, 'Micro Center', '1555 W Lane Ave', None, 'Columbus', 'OH', '43221', '(614) 555-4435', 'Evan', 'Emily', 2, 160),
#  (23, 'Yale Industrial Trucks-Fresno', '3711 W Franklin', None, 'Fresno', 'CA', '93706', '(559) 555-2993', 'Alexis', 'Alexandro', 3, 532),
#  (24, 'Zee Medical Service Co', '4221 W Sierra Madre #104', None, 'Washington', 'IA', '52353', None, 'Hallie', 'Juliana', 3, 570),
#  (25, 'California Data Marketing', '2818 E Hamilton', None, 'Fresno', 'CA', '93721', '(559) 555-3801', 'Jonessen', 'Moises', 4, 540),
#  (26, 'Small Press', '121 E Front St - 4th Floor', None, 'Traverse City', 'MI', '49684', None, 'Colette', 'Dusty', 3, 540),
#  (27, 'Rich Advertising', '12 Daniel Road', None, 'Fairfield', 'NJ', '07004', '(201) 555-9742', 'Neil', 'Ingrid', 3, 540),
#  (29, 'Vision Envelope & Printing', 'PO Box 3100', None, 'Gardena', 'CA', '90247', '(310) 555-7062', 'Raven', 'Jamari', 3, 551),
#  (30, 'Costco', 'Fresno Warehouse', '4500 W Shaw', 'Fresno', 'CA', '93711', None, 'Jaquan', 'Aaron', 3, 570),
#  (31, 'Enterprise Communications Inc', '1483 Chain Bridge Rd, Ste 202', None, 'Mclean', 'VA', '22101', '(770) 555-9558', 'Lawrence', 'Eileen', 2, 536),
#  (32, 'RR Bowker', 'PO Box 31', None, 'East Brunswick', 'NJ', '08810', '(800) 555-8110', 'Essence', 'Marjorie', 3, 532),
#  (33, 'Nielson', 'Ohio Valley Litho Division', 'Location #0470', 'Cincinnati', 'OH', '45264', None, 'Brooklynn', 'Keely', 2, 541),
#  (34, 'IBM', 'PO Box 61000', None, 'San Francisco', 'CA', '94161', '(800) 555-4426', 'Camron', 'Trentin', 1, 160),
#  (35, 'Cal State Termite', 'PO Box 956', None, 'Selma', 'CA', '93662', '(559) 555-1534', 'Hunter', 'Demetrius', 2, 523),
#  (36, 'Graylift', 'PO Box 2808', None, 'Fresno', 'CA', '93745', '(559) 555-6621', 'Sydney', 'Deangelo', 3, 532),
#  (37, 'Blue Cross', 'PO Box 9061', None, 'Oxnard', 'CA', '93031', '(800) 555-0912', 'Eliana', 'Nikolas', 3, 510),
#  (38, "Venture Communications Int'l", '60 Madison Ave', None, 'New York', 'NY', '10010', '(212) 555-4800', 'Neftaly', 'Thalia', 3, 540),
#  (39, 'Custom Printing Company', 'PO Box 7028', None, 'St Louis', 'MO', '63177', '(301) 555-1494', 'Myles', 'Harley', 3, 540),
#  (40, 'Nat Assoc of College Stores', '500 East Lorain Street', None, 'Oberlin', 'OH', '44074', None, 'Bernard', 'Lucy', 3, 572),
#  (41, 'Shields Design', '415 E Olive Ave', None, 'Fresno', 'CA', '93728', '(559) 555-8060', 'Kerry', 'Rowan', 2, 403),
#  (42, 'Opamp Technical Books', '1033 N Sycamore Ave.', None, 'Los Angeles', 'CA', '90038', '(213) 555-4322', 'Paris', 'Gideon', 3, 572),
#  (43, 'Capital Resource Credit', 'PO Box 39046', None, 'Minneapolis', 'MN', '55439', '(612) 555-0057', 'Maxwell', 'Jayda', 3, 589),
#  (44, 'Courier Companies, Inc', 'PO Box 5317', None, 'Boston', 'MA', '02206', '(508) 555-6351', 'Antavius', 'Troy', 4, 403),
#  (45, 'Naylor Publications Inc', 'PO Box 40513', None, 'Jacksonville', 'FL', '32231', '(800) 555-6041', 'Gerald', 'Kristofer', 3, 572),
#  (46, 'Open Horizons Publishing', 'Book Marketing Update', 'PO Box 205', 'Fairfield', 'IA', '52556', '(515) 555-6130', 'Damien', 'Deborah', 2, 540),
#  (47, 'Baker & Taylor Books', 'Five Lakepointe Plaza, Ste 500', '2709 Water Ridge Parkway', 'Charlotte', 'NC', '28217', '(704) 555-3500', 'Bernardo', 'Brittnee', 3, 572),
#  (48, 'Fresno County Tax Collector', 'PO Box 1192', None, 'Fresno', 'CA', '93715', '(559) 555-3482', 'Brenton', 'Kila', 3, 574),
#  (49, 'Mcgraw Hill Companies', 'PO Box 87373', None, 'Chicago', 'IL', '60680', '(614) 555-3663', 'Holbrooke', 'Rashad', 3, 572),
#  (50, 'Publishers Weekly', 'Box 1979', None, 'Marion', 'OH', '43305', '(800) 555-1669', 'Carrollton', 'Priscilla', 3, 572),
#  (51, 'Blue Shield of California', 'PO Box 7021', None, 'Anaheim', 'CA', '92850', '(415) 555-5103', 'Smith', 'Kylie', 3, 510),
#  (52, 'Aztek Label', 'Accounts Payable', '1150 N Tustin Ave', 'Anaheim', 'CA', '92807', '(714) 555-9000', 'Griffin', 'Brian', 3, 551),
#  (53, 'Gary McKeighan Insurance', '3649 W Beechwood Ave #101', None, 'Fresno', 'CA', '93711', '(559) 555-2420', 'Jair', 'Caitlin', 3, 590),
#  (54, 'Ph Photographic Services', '2384 E Gettysburg', None, 'Fresno', 'CA', '93726', '(559) 555-0765', 'Cheyenne', 'Kaylea', 3, 540),
#  (55, 'Quality Education Data', 'PO Box 95857', None, 'Chicago', 'IL', '60694', '(800) 555-5811', 'Misael', 'Kayle', 2, 540),
#  (56, 'Springhouse Corp', 'PO Box 7247-7051', None, 'Philadelphia', 'PA', '19170', '(215) 555-8700', 'Maeve', 'Clarence', 3, 523),
#  (57, 'The Windows Deck', '117 W Micheltorena Top Floor', None, 'Santa Barbara', 'CA', '93101', '(800) 555-3353', 'Wood', 'Liam', 3, 536),
#  (58, 'Fresno Rack & Shelving Inc', '4718 N Bendel Ave', None, 'Fresno', 'CA', '93722', None, 'Baylee', 'Dakota', 2, 523),
#  (59, 'Publishers Marketing Assoc', '627 Aviation Way', None, 'Manhatttan Beach', 'CA', '90266', '(310) 555-2732', 'Walker', 'Jovon', 3, 572),
#  (60, 'The Mailers Guide Co', 'PO Box 1550', None, 'New Rochelle', 'NY', '10802', None, 'Lacy', 'Karina', 3, 540),
#  (61, 'American Booksellers Assoc', '828 S Broadway', None, 'Tarrytown', 'NY', '10591', '(800) 555-0037', 'Angelica', 'Nashalie', 3, 574),
#  (62, 'Cmg Information Services', 'PO Box 2283', None, 'Boston', 'MA', '02107', '(508) 555-7000', 'Randall', 'Yash', 3, 540),
#  (63, "Lou Gentile's Flower Basket", '722 E Olive Ave', None, 'Fresno', 'CA', '93728', '(559) 555-6643', 'Anum', 'Trisha', 1, 570),
#  (64, 'Texaco', 'PO Box 6070', None, 'Inglewood', 'CA', '90312', None, 'Oren', 'Grace', 3, 582),
#  (65, 'The Drawing Board', 'PO Box 4758', None, 'Carol Stream', 'IL', '60197', None, 'Mckayla', 'Jeffery', 2, 551),
#  (66, 'Ascom Hasler Mailing Systems', 'PO Box 895', None, 'Shelton', 'CT', '06484', None, 'Lewis', 'Darnell', 3, 532),
#  (67, 'Bill Jones', 'Secretary Of State', 'PO Box 944230', 'Sacramento', 'CA', '94244', None, 'Deasia', 'Tristin', 3, 589),
#  (68, 'Computer Library', '3502 W Greenway #7', None, 'Phoenix', 'AZ', '85023', '(602) 547-0331', 'Aryn', 'Leroy', 3, 540),
#  (69, 'Frank E Wilber Co', '2437 N Sunnyside', None, 'Fresno', 'CA', '93727', '(559) 555-1881', 'Millerton', 'Johnathon', 3, 532),
#  (70, 'Fresno Credit Bureau', 'PO Box 942', None, 'Fresno', 'CA', '93714', '(559) 555-7900', 'Braydon', 'Anne', 2, 555),
#  (71, 'The Fresno Bee', '1626 E Street', None, 'Fresno', 'CA', '93786', '(559) 555-4442', 'Colton', 'Leah', 2, 572),
#  (72, 'Data Reproductions Corp', '4545 Glenmeade Lane', None, 'Auburn Hills', 'MI', '48326', '(810) 555-3700', 'Arodondo', 'Cesar', 3, 400),
#  (73, 'Executive Office Products', '353 E Shaw Ave', None, 'Fresno', 'CA', '93710', '(559) 555-1704', 'Danielson', 'Rachael', 2, 570),
#  (74, 'Leslie Company', 'PO Box 610', None, 'Olathe', 'KS', '66061', '(800) 255-6210', 'Alondra', 'Zev', 3, 570),
#  (75, 'Retirement Plan Consultants', '6435 North Palm Ave, Ste 101', None, 'Fresno', 'CA', '93704', '(559) 555-7070', 'Edgardo', 'Salina', 3, 589),
#  (76, 'Simon Direct Inc', '4 Cornwall Dr Ste 102', None, 'East Brunswick', 'NJ', '08816', '(908) 555-7222', 'Bradlee', 'Daniel', 2, 540),
#  (77, 'State Board Of Equalization', 'PO Box 942808', None, 'Sacramento', 'CA', '94208', '(916) 555-4911', 'Dean', 'Julissa', 1, 631),
#  (78, 'The Presort Center', '1627 "E" Street', None, 'Fresno', 'CA', '93706', '(559) 555-6151', 'Marissa', 'Kyle', 3, 540),
#  (79, 'Valprint', 'PO Box 12332', None, 'Fresno', 'CA', '93777', '(559) 555-3112', 'Warren', 'Quentin', 3, 551),
#  (80, 'Cardinal Business Media, Inc.', 'P O Box 7247-7844', None, 'Philadelphia', 'PA', '19170', '(215) 555-1500', 'Eulalia', 'Kelsey', 2, 540),
#  (81, 'Wang Laboratories, Inc.', 'P.O. Box 21209', None, 'Pasadena', 'CA', '91185', '(800) 555-0344', 'Kapil', 'Robert', 2, 160),
#  (82, "Reiter's Scientific & Pro Books", '2021 K Street Nw', None, 'Washington', 'DC', '20006', '(202) 555-5561', 'Rodolfo', 'Carlee', 2, 572),
#  (83, 'Ingram', 'PO Box 845361', None, 'Dallas', 'TX', '75284', None, 'Yobani', 'Trey', 2, 541),
#  (84, 'Boucher Communications Inc', '1300 Virginia Dr. Ste 400', None, 'Fort Washington', 'PA', '19034', '(215) 555-8000', 'Carson', 'Julian', 3, 540),
#  (85, 'Champion Printing Company', '3250 Spring Grove Ave', None, 'Cincinnati', 'OH', '45225', '(800) 555-1957', 'Clifford', 'Jillian', 3, 540),
#  (86, 'Computerworld', 'Department #1872', 'PO Box 61000', 'San Francisco', 'CA', '94161', '(617) 555-0700', 'Lloyd', 'Angel', 1, 572),
#  (87, 'DMV Renewal', 'PO Box 942894', None, 'Sacramento', 'CA', '94294', None, 'Josey', 'Lorena', 4, 568),
#  (88, 'Edward Data Services', '4775 E Miami River Rd', None, 'Cleves', 'OH', '45002', '(513) 555-3043', 'Helena', 'Jeanette', 1, 540),
#  (89, 'Evans Executone Inc', '4918 Taylor Ct', None, 'Turlock', 'CA', '95380', None, 'Royce', 'Hannah', 1, 522),
#  (90, 'Wakefield Co', '295 W Cromwell Ave Ste 106', None, 'Fresno', 'CA', '93711', '(559) 555-4744', 'Rothman', 'Nathanael', 2, 170),
#  (91, 'McKesson Water Products', 'P O Box 7126', None, 'Pasadena', 'CA', '91109', '(800) 555-7009', 'Destin', 'Luciano', 2, 570),
#  (92, 'Zip Print & Copy Center', 'PO Box 12332', None, 'Fresno', 'CA', '93777', '(233) 555-6400', 'Javen', 'Justin', 2, 540),
#  (93, 'AT&T', 'PO Box 78225', None, 'Phoenix', 'AZ', '85062', None, 'Wesley', 'Alisha', 3, 522),
#  (94, 'Abbey Office Furnishings', '4150 W Shaw Ave', None, 'Fresno', 'CA', '93722', '(559) 555-8300', 'Francis', 'Kyra', 2, 150),
#  (95, 'Pacific Bell', None, None, 'Sacramento', 'CA', '95887', '(209) 555-7500', 'Nickalus', 'Kurt', 2, 522),
#  (96, 'Wells Fargo Bank', 'Business Mastercard', 'P.O. Box 29479', 'Phoenix', 'AZ', '85038', '(947) 555-3900', 'Damion', 'Mikayla', 2, 160),
#  (97, 'Compuserve', 'Dept L-742', None, 'Columbus', 'OH', '43260', '(614) 555-8600', 'Armando', 'Jan', 2, 572),
#  (98, 'American Express', 'Box 0001', None, 'Los Angeles', 'CA', '90096', '(800) 555-3344', 'Story', 'Kirsten', 2, 160),
#  (99, 'Bertelsmann Industry Svcs. Inc', '28210 N Avenue Stanford', None, 'Valencia', 'CA', '91355', '(805) 555-0584', 'Potter', 'Lance', 3, 400),
#  (100, 'Cahners Publishing Company', 'Citibank Lock Box 4026', '8725 W Sahara Zone 1127', 'The Lake', 'NV', '89163', '(301) 555-2162', 'Jacobsen', 'Samuel', 4, 540),
#  (101, 'California Business Machines', 'Gallery Plz', '5091 N Fresno', 'Fresno', 'CA', '93710', '(559) 555-5570', 'Rohansen', 'Anders', 2, 170),
#  (102, 'Coffee Break Service', 'PO Box 1091', None, 'Fresno', 'CA', '93714', '(559) 555-8700', 'Smitzen', 'Jeffrey', 4, 570),
#  (103, 'Dean Witter Reynolds', '9 River Pk Pl E 400', None, 'Boston', 'MA', '02134', '(508) 555-8737', 'Johnson', 'Vance', 5, 589),
#  (104, 'Digital Dreamworks', '5070 N Sixth Ste. 71', None, 'Fresno', 'CA', '93711', None, 'Elmert', 'Ron', 3, 589),
#  (105, 'Dristas Groom & McCormick', '7112 N Fresno St Ste 200', None, 'Fresno', 'CA', '93720', '(559) 555-8484', 'Aaronsen', 'Thom', 3, 591),
#  (106, 'Ford Motor Credit Company', 'Dept 0419', None, 'Los Angeles', 'CA', '90084', '(800) 555-7000', 'Snyder', 'Karen', 3, 582),
#  (107, 'Franchise Tax Board', 'PO Box 942857', None, 'Sacramento', 'CA', '94257', None, 'Prado', 'Anita', 4, 507),
#  (108, 'Gostanian General Building', '427 W Bedford #102', None, 'Fresno', 'CA', '93711', '(559) 555-5100', 'Bragg', 'Walter', 4, 523),
#  (109, 'Kent H Landsberg Co', 'File No 72686', 'PO Box 61000', 'San Francisco', 'CA', '94160', '(916) 555-8100', 'Stevens', 'Wendy', 3, 540),
#  (110, 'Malloy Lithographing Inc', '5411 Jackson Road', 'PO Box 1124', 'Ann Arbor', 'MI', '48106', '(313) 555-6113', 'Regging', 'Abe', 3, 400),
#  (111, 'Net Asset, Llc', '1315 Van Ness Ave Ste. 103', None, 'Fresno', 'CA', '93721', None, 'Kraggin', 'Laura', 1, 572),
#  (112, 'Office Depot', 'File No 81901', None, 'Los Angeles', 'CA', '90074', '(800) 555-1711', 'Pinsippi', 'Val', 3, 570),
#  (113, 'Pollstar', '4697 W Jacquelyn Ave', None, 'Fresno', 'CA', '93722', '(559) 555-2631', 'Aranovitch', 'Robert', 5, 520),
#  (114, 'Postmaster', 'Postage Due Technician', '1900 E Street', 'Fresno', 'CA', '93706', '(559) 555-7785', 'Finklestein', 'Fyodor', 1, 552),
#  (115, 'Roadway Package System, Inc', 'Dept La 21095', None, 'Pasadena', 'CA', '91185', None, 'Smith', 'Sam', 4, 553),
#  (116, 'State of California', 'Employment Development Dept', 'PO Box 826276', 'Sacramento', 'CA', '94230', '(209) 555-5132', 'Articunia', 'Mercedez', 1, 631),
#  (117, 'Suburban Propane', '2874 S Cherry Ave', None, 'Fresno', 'CA', '93706', '(559) 555-2770', 'Spivak', 'Harold', 3, 521),
#  (118, 'Unocal', 'P.O. Box 860070', None, 'Pasadena', 'CA', '91186', '(415) 555-7600', 'Bluzinski', 'Rachael', 3, 582),
#  (119, 'Yesmed, Inc', 'PO Box 2061', None, 'Fresno', 'CA', '93718', '(559) 555-0600', 'Hernandez', 'Reba', 2, 589),
#  (120, 'Dataforms/West', '1617 W. Shaw Avenue', 'Suite F', 'Fresno', 'CA', '93711', None, 'Church', 'Charlie', 3, 551),
#  (121, 'Zylka Design', '3467 W Shaw Ave #103', None, 'Fresno', 'CA', '93711', '(559) 555-8625', 'Ronaldsen', 'Jaime', 3, 403),
#  (122, 'United Parcel Service', 'P.O. Box 505820', None, 'Reno', 'NV', '88905', '(800) 555-0855', 'Beauregard', 'Violet', 3, 553),
#  (123, 'Federal Express Corporation', 'P.O. Box 1140', 'Dept A', 'Memphis', 'TN', '38101', '(800) 555-4091', 'Bucket', 'Charlie', 3, 553)]

# %%
# %%sql #4 A statement that return a row for each line item of each invoice that has more than one line item in the Invoice_line_item table
#
# SELECT vendor_name, i.invoice_id, invoice_sequence, line_item_amount
# FROM Invoices i
#   JOIN Vendors v ON i.vendor_id = v.vendor_id
#   JOIN Invoice_line_items li ON i.invoice_id = li.invoice_id
# WHERE invoice_sequence IN (
#   SELECT invoice_sequence
#   FROM Invoice_line_items
#   WHERE invoice_sequence = 1
# )
# ORDER BY vendor_name, invoice_id;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 109 rows affected.
# [('Abbey Office Furnishings', 82, 1, Decimal('17.50')),
#  ('Bertelsmann Industry Svcs. Inc', 65, 1, Decimal('6940.25')),
#  ('Blue Cross', 46, 1, Decimal('224.00')),
#  ('Blue Cross', 50, 1, Decimal('116.00')),
#  ('Blue Cross', 113, 1, Decimal('224.00')),
#  ('Cahners Publishing Company', 79, 1, Decimal('2184.50')),
#  ('Cardinal Business Media, Inc.', 69, 1, Decimal('175.00')),
#  ('Cardinal Business Media, Inc.', 110, 1, Decimal('90.36')),
#  ('Coffee Break Service', 74, 1, Decimal('41.80')),
#  ('Compuserve', 16, 1, Decimal('9.95')),
#  ('Compuserve', 23, 1, Decimal('9.95')),
#  ('Computerworld', 56, 1, Decimal('2433.00')),
#  ('Data Reproductions Corp', 43, 1, Decimal('21842.00')),
#  ('Data Reproductions Corp', 89, 1, Decimal('85.31')),
#  ('Dean Witter Reynolds', 57, 1, Decimal('1367.50')),
#  ('Digital Dreamworks', 31, 1, Decimal('7125.34')),
#  ('Dristas Groom & McCormick', 33, 1, Decimal('220.00')),
#  ('Edward Data Services', 27, 1, Decimal('207.78')),
#  ('Evans Executone Inc', 8, 1, Decimal('95.00')),
#  ('Federal Express Corporation', 2, 1, Decimal('40.20')),
#  ('Federal Express Corporation', 3, 1, Decimal('138.75')),
#  ('Federal Express Corporation', 4, 1, Decimal('144.70')),
#  ('Federal Express Corporation', 5, 1, Decimal('15.50')),
#  ('Federal Express Corporation', 6, 1, Decimal('42.75')),
#  ('Federal Express Corporation', 7, 1, Decimal('172.50')),
#  ('Federal Express Corporation', 10, 1, Decimal('42.67')),
#  ('Federal Express Corporation', 11, 1, Decimal('42.50')),
#  ('Federal Express Corporation', 17, 1, Decimal('10.00')),
#  ('Federal Express Corporation', 18, 1, Decimal('104.00')),
#  ('Federal Express Corporation', 22, 1, Decimal('108.25')),
#  ('Federal Express Corporation', 25, 1, Decimal('129.00')),
#  ('Federal Express Corporation', 26, 1, Decimal('10.00')),
#  ('Federal Express Corporation', 28, 1, Decimal('109.50')),
#  ('Federal Express Corporation', 30, 1, Decimal('63.40')),
#  ('Federal Express Corporation', 34, 1, Decimal('127.75')),
#  ('Federal Express Corporation', 37, 1, Decimal('36.00')),
#  ('Federal Express Corporation', 38, 1, Decimal('61.50')),
#  ('Federal Express Corporation', 41, 1, Decimal('53.75')),
#  ('Federal Express Corporation', 42, 1, Decimal('400.00')),
#  ('Federal Express Corporation', 48, 1, Decimal('33.00')),
#  ('Federal Express Corporation', 55, 1, Decimal('40.75')),
#  ('Federal Express Corporation', 58, 1, Decimal('53.25')),
#  ('Federal Express Corporation', 59, 1, Decimal('13.75')),
#  ('Federal Express Corporation', 62, 1, Decimal('26.75')),
#  ('Federal Express Corporation', 64, 1, Decimal('23.50')),
#  ('Federal Express Corporation', 66, 1, Decimal('31.95')),
#  ('Federal Express Corporation', 71, 1, Decimal('108.50')),
#  ('Federal Express Corporation', 72, 1, Decimal('10.00')),
#  ('Federal Express Corporation', 75, 1, Decimal('27.00')),
#  ('Federal Express Corporation', 76, 1, Decimal('241.00')),
#  ('Federal Express Corporation', 81, 1, Decimal('26.25')),
#  ('Federal Express Corporation', 84, 1, Decimal('111.00')),
#  ('Federal Express Corporation', 85, 1, Decimal('158.00')),
#  ('Federal Express Corporation', 86, 1, Decimal('739.20')),
#  ('Federal Express Corporation', 87, 1, Decimal('60.00')),
#  ('Federal Express Corporation', 88, 1, Decimal('147.25')),
#  ('Federal Express Corporation', 90, 1, Decimal('38.75')),
#  ('Federal Express Corporation', 93, 1, Decimal('162.75')),
#  ('Federal Express Corporation', 94, 1, Decimal('52.25')),
#  ('Federal Express Corporation', 99, 1, Decimal('59.97')),
#  ('Federal Express Corporation', 100, 1, Decimal('67.92')),
#  ('Federal Express Corporation', 101, 1, Decimal('30.75')),
#  ('Federal Express Corporation', 104, 1, Decimal('44.44')),
#  ('Federal Express Corporation', 108, 1, Decimal('67.00')),
#  ('Federal Express Corporation', 111, 1, Decimal('22.57')),
#  ('Federal Express Corporation', 114, 1, Decimal('127.75')),
#  ('Ford Motor Credit Company', 105, 1, Decimal('503.20')),
#  ('Franchise Tax Board', 35, 1, Decimal('1600.00')),
#  ('Fresno County Tax Collector', 15, 1, Decimal('856.92')),
#  ('Gostanian General Building', 29, 1, Decimal('450.00')),
#  ('IBM', 19, 1, Decimal('116.54')),
#  ('IBM', 52, 1, Decimal('1083.58')),
#  ('Ingram', 47, 1, Decimal('1575.00')),
#  ('Ingram', 98, 1, Decimal('579.42')),
#  ('Malloy Lithographing Inc', 39, 1, Decimal('37966.19')),
#  ('Malloy Lithographing Inc', 96, 1, Decimal('26881.40')),
#  ('Malloy Lithographing Inc', 102, 1, Decimal('20551.18')),
#  ('Malloy Lithographing Inc', 106, 1, Decimal('23517.58')),
#  ('Malloy Lithographing Inc', 112, 1, Decimal('10976.06')),
#  ('Pacific Bell', 13, 1, Decimal('16.33')),
#  ('Pacific Bell', 44, 1, Decimal('19.67')),
#  ('Pacific Bell', 49, 1, Decimal('16.33')),
#  ('Pacific Bell', 53, 1, Decimal('46.21')),
#  ('Pacific Bell', 83, 1, Decimal('39.77')),
#  ('Pacific Bell', 91, 1, Decimal('32.70')),
#  ('Pollstar', 24, 1, Decimal('1750.00')),
#  ('Postmaster', 73, 1, Decimal('290.00')),
#  ("Reiter's Scientific & Pro Books", 95, 1, Decimal('600.00')),
#  ('Suburban Propane', 92, 1, Decimal('16.62')),
#  ('United Parcel Service', 1, 1, Decimal('3813.33')),
#  ('United Parcel Service', 45, 1, Decimal('2765.36')),
#  ('United Parcel Service', 51, 1, Decimal('2184.11')),
#  ('United Parcel Service', 60, 1, Decimal('2312.20')),
#  ('United Parcel Service', 63, 1, Decimal('2115.81')),
#  ('United Parcel Service', 67, 1, Decimal('1927.54')),
#  ('United Parcel Service', 80, 1, Decimal('2318.03')),
#  ('United Parcel Service', 103, 1, Decimal('2051.59')),
#  ('United Parcel Service', 107, 1, Decimal('3689.99')),
#  ('Wakefield Co', 97, 1, Decimal('356.48')),
#  ('Wang Laboratories, Inc.', 68, 1, Decimal('936.93')),
#  ('Yesmed, Inc', 21, 1, Decimal('4901.26')),
#  ('Zylka Design', 9, 1, Decimal('601.95')),
#  ('Zylka Design', 32, 1, Decimal('953.10')),
#  ('Zylka Design', 36, 1, Decimal('565.15')),
#  ('Zylka Design', 40, 1, Decimal('639.77')),
#  ('Zylka Design', 54, 1, Decimal('313.55')),
#  ('Zylka Design', 77, 1, Decimal('904.14')),
#  ('Zylka Design', 78, 1, Decimal('1197.00')),
#  ('Zylka Design', 109, 1, Decimal('1000.46'))]

# %%
# %%sql #5 Statement that returns the largest unpaid invoice for each vendor
#
# SELECT vendor_id, MAX(invoice_total) AS largest_unpaid
# FROM Invoices
# WHERE invoice_total - credit_total - payment_total > 0
# GROUP BY vendor_id;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 8 rows affected.
# [(37, Decimal('224.00')),
#  (72, Decimal('85.31')),
#  (80, Decimal('90.36')),
#  (83, Decimal('579.42')),
#  (97, Decimal('8344.50')),
#  (106, Decimal('503.20')),
#  (110, Decimal('20551.18')),
#  (123, Decimal('67.92'))]

# %%
# %%sql #5 statement that returns a sum of the largest unpaid invoices for each vendor
#
# SELECT SUM(largest_unpaid) AS sum_largest_unpaid
# FROM (
#   SELECT vendor_id, MAX(invoice_total) AS largest_unpaid
#   FROM Invoices
#   WHERE invoice_total - credit_total - payment_total > 0
#   GROUP BY vendor_id
# )t;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 1 rows affected.
# [(Decimal('30445.89'),)]
