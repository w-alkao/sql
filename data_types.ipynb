# %%
# %load_ext sql

# %%
# %%sql
# mysql+pymysql://w-alkao:mypassword@localhost

# %%
# %sql SHOW DATABASES;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 8 rows affected.
# [('ap',),
#  ('ex',),
#  ('information_schema',),
#  ('livestock',),
#  ('mysql',),
#  ('om',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %sql USE ap;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# ### Overview Data types
#
# * **Character**: Strings of character data
# * **Numeric**: Numbers that don't include a decimal point (integers) and numbers that include a decimal point (real numbers)
# * **Date and time**: Dates, times, or both
# * **Large Object(LOB)**: Large strings of character or binary data
# * **Spatial**: Geographical values
# * **JSON**: JSON documents

# %% [markdown]
# ### Convert data

# %%
# %sql SELECT * FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(1, 122, '989319-457', datetime.date(2018, 4, 8), Decimal('3813.33'), Decimal('3813.33'), Decimal('0.00'), 1, datetime.date(2018, 5, 8), datetime.date(2018, 5, 7)),
#  (2, 123, '263253241', datetime.date(2018, 4, 10), Decimal('40.20'), Decimal('40.20'), Decimal('0.00'), 3, datetime.date(2018, 5, 10), datetime.date(2018, 5, 14)),
#  (3, 123, '963253234', datetime.date(2018, 4, 13), Decimal('138.75'), Decimal('138.75'), Decimal('0.00'), 3, datetime.date(2018, 5, 13), datetime.date(2018, 5, 9)),
#  (4, 123, '2-000-2993', datetime.date(2018, 4, 16), Decimal('144.70'), Decimal('144.70'), Decimal('0.00'), 3, datetime.date(2018, 5, 16), datetime.date(2018, 5, 12)),
#  (5, 123, '963253251', datetime.date(2018, 4, 16), Decimal('15.50'), Decimal('15.50'), Decimal('0.00'), 3, datetime.date(2018, 5, 16), datetime.date(2018, 5, 11)),
# ...

# %%
# %sql DESCRIBE Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 10 rows affected.
# [('invoice_id', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('vendor_id', 'int', 'NO', 'MUL', None, ''),
#  ('invoice_number', 'varchar(50)', 'NO', '', None, ''),
#  ('invoice_date', 'date', 'NO', 'MUL', None, ''),
#  ('invoice_total', 'decimal(9,2)', 'NO', '', None, ''),
#  ('payment_total', 'decimal(9,2)', 'NO', '', '0.00', ''),
#  ('credit_total', 'decimal(9,2)', 'NO', '', '0.00', ''),
#  ('terms_id', 'int', 'NO', 'MUL', None, ''),
#  ('invoice_due_date', 'date', 'NO', '', None, ''),
#  ('payment_date', 'date', 'YES', '', None, '')]

# %%
# %%sql # Convert number to string
#
# SELECT invoice_total, CONCAT('$', invoice_total)
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(Decimal('3813.33'), '$3813.33'),
#  (Decimal('40.20'), '$40.20'),
#  (Decimal('138.75'), '$138.75'),
#  (Decimal('144.70'), '$144.70'),
#  (Decimal('15.50'), '$15.50'),
#  (Decimal('42.75'), '$42.75'),
#  (Decimal('172.50'), '$172.50'),
#  (Decimal('95.00'), '$95.00'),
#  (Decimal('601.95'), '$601.95'),
#  (Decimal('42.67'), '$42.67'),
#  (Decimal('42.50'), '$42.50'),
#  (Decimal('662.00'), '$662.00'),
#  (Decimal('16.33'), '$16.33'),
#  (Decimal('6.00'), '$6.00'),
#  (Decimal('856.92'), '$856.92'),
#  (Decimal('9.95'), '$9.95'),
#  (Decimal('10.00'), '$10.00'),
#  (Decimal('104.00'), '$104.00'),
#  (Decimal('116.54'), '$116.54'),
#  (Decimal('6.00'), '$6.00'),
#  (Decimal('4901.26'), '$4901.26'),
#  (Decimal('108.25'), '$108.25'),
#  (Decimal('9.95'), '$9.95'),
#  (Decimal('1750.00'), '$1750.00'),
#  (Decimal('129.00'), '$129.00'),
#  (Decimal('10.00'), '$10.00'),
#  (Decimal('207.78'), '$207.78'),
# ...

# %%
# %%sql # Convert string to number
#
# SELECT invoice_number, 989319/invoice_number
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [('989319-457', 1.0),
#  ('263253241', 0.0037580505988908225),
#  ('963253234', 0.0010270601385803393),
#  ('2-000-2993', 494659.5),
#  ('963253251', 0.0010270601204542418),
#  ('963253261', 0.0010270601097918319),
#  ('963253237', 0.001027060135381616),
#  ('125520-1', 7.881763862332696),
#  ('97/488', 10199.164948453608),
#  ('263253250', 0.0037580504704120463),
#  ('963253262', 0.0010270601087255908),
#  ('I77271-O01', None),
#  ('111-92R-10096', 8912.783783783783),
#  ('25022117', 0.039537781715272134),
#  ('P02-88D77S7', None),
#  ('21-4748363', 47110.42857142857),
#  ('4-321-2596', 247329.75),
#  ('963253242', 0.001027060130050411),
#  ('QP58872', None),
#  ('24863706', 0.03978968380658941),
#  ('10843', 91.24033938946786),
#  ('963253235', 0.0010270601375140982),
#  ('21-4923721', 47110.42857142857),
#  ('77290', 12.800090567990685),
#  ('963253246', 0.001027060125785447),
#  ('4-342-8069', 247329.75),
# ...

# %%
# %%sql # Convert date to number
#
# SELECT invoice_date, invoice_date + 1
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(datetime.date(2018, 8, 3), 20180804),
#  (datetime.date(2018, 8, 3), 20180804),
#  (datetime.date(2018, 8, 2), 20180803),
#  (datetime.date(2018, 8, 2), 20180803),
#  (datetime.date(2018, 8, 1), 20180802),
#  (datetime.date(2018, 8, 1), 20180802),
#  (datetime.date(2018, 8, 1), 20180802),
#  (datetime.date(2018, 7, 31), 20180732),
#  (datetime.date(2018, 7, 30), 20180731),
#  (datetime.date(2018, 7, 28), 20180729),
#  (datetime.date(2018, 7, 25), 20180726),
#  (datetime.date(2018, 7, 24), 20180725),
#  (datetime.date(2018, 7, 24), 20180725),
#  (datetime.date(2018, 7, 24), 20180725),
#  (datetime.date(2018, 7, 24), 20180725),
#  (datetime.date(2018, 7, 23), 20180724),
#  (datetime.date(2018, 7, 23), 20180724),
#  (datetime.date(2018, 7, 23), 20180724),
#  (datetime.date(2018, 7, 22), 20180723),
#  (datetime.date(2018, 7, 22), 20180723),
#  (datetime.date(2018, 7, 21), 20180722),
# ...

# %%
# %%sql # use of cast function
#
# SELECT invoice_id, invoice_date, invoice_total,
#   CAST(invoice_date AS CHAR(10)) AS date_to_char,
#   CAST(credit_total AS SIGNED) AS interger_tota
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(1, datetime.date(2018, 4, 8), Decimal('3813.33'), '2018-04-08', 0),
#  (2, datetime.date(2018, 4, 10), Decimal('40.20'), '2018-04-10', 0),
#  (3, datetime.date(2018, 4, 13), Decimal('138.75'), '2018-04-13', 0),
#  (4, datetime.date(2018, 4, 16), Decimal('144.70'), '2018-04-16', 0),
#  (5, datetime.date(2018, 4, 16), Decimal('15.50'), '2018-04-16', 0),
#  (6, datetime.date(2018, 4, 16), Decimal('42.75'), '2018-04-16', 0),
#  (7, datetime.date(2018, 4, 21), Decimal('172.50'), '2018-04-21', 0),
#  (8, datetime.date(2018, 4, 24), Decimal('95.00'), '2018-04-24', 0),
#  (9, datetime.date(2018, 4, 24), Decimal('601.95'), '2018-04-24', 0),
#  (10, datetime.date(2018, 4, 24), Decimal('42.67'), '2018-04-24', 0),
#  (11, datetime.date(2018, 4, 25), Decimal('42.50'), '2018-04-25', 0),
#  (12, datetime.date(2018, 4, 26), Decimal('662.00'), '2018-04-26', 0),
#  (13, datetime.date(2018, 4, 30), Decimal('16.33'), '2018-04-30', 0),
# ...

# %%
# %%sql # use of convert function
#
# SELECT invoice_id, invoice_date, invoice_total,
#   CONVERT(invoice_date, CHAR(10)) AS char_date,
#   CONVERT(invoice_total, SIGNED) AS integer_total
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(1, datetime.date(2018, 4, 8), Decimal('3813.33'), '2018-04-08', 3813),
#  (2, datetime.date(2018, 4, 10), Decimal('40.20'), '2018-04-10', 40),
#  (3, datetime.date(2018, 4, 13), Decimal('138.75'), '2018-04-13', 139),
#  (4, datetime.date(2018, 4, 16), Decimal('144.70'), '2018-04-16', 145),
#  (5, datetime.date(2018, 4, 16), Decimal('15.50'), '2018-04-16', 16),
#  (6, datetime.date(2018, 4, 16), Decimal('42.75'), '2018-04-16', 43),
#  (7, datetime.date(2018, 4, 21), Decimal('172.50'), '2018-04-21', 173),
#  (8, datetime.date(2018, 4, 24), Decimal('95.00'), '2018-04-24', 95),
#  (9, datetime.date(2018, 4, 24), Decimal('601.95'), '2018-04-24', 602),
#  (10, datetime.date(2018, 4, 24), Decimal('42.67'), '2018-04-24', 43),
#  (11, datetime.date(2018, 4, 25), Decimal('42.50'), '2018-04-25', 43),
#  (12, datetime.date(2018, 4, 26), Decimal('662.00'), '2018-04-26', 662),
# ...

# %%
# %%sql # use of the char function to format output
#
# SELECT CONCAT(vendor_name, CHAR(13,10), vendor_address1, CHAR(13,10),
#               vendor_city, ', ', vendor_state, ' ', vendor_zip_code) AS format_output
# FROM Vendors
# WHERE vendor_id = 1;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 1 rows affected.
# [('US Postal Service\r\nAttn:  Supt. Window Services\r\nMadison, WI 53707',)]

# %% [markdown]
# ### Extra

# %%
# %%sql #
#
# SELECT invoice_total,
#   FORMAT(invoice_total, 1),
#   CONVERT(invoice_total, SIGNED),
#   CAST(invoice_total AS SIGNED)
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(Decimal('3813.33'), '3,813.3', 3813, 3813),
#  (Decimal('40.20'), '40.2', 40, 40),
#  (Decimal('138.75'), '138.8', 139, 139),
#  (Decimal('144.70'), '144.7', 145, 145),
#  (Decimal('15.50'), '15.5', 16, 16),
#  (Decimal('42.75'), '42.8', 43, 43),
#  (Decimal('172.50'), '172.5', 173, 173),
#  (Decimal('95.00'), '95.0', 95, 95),
#  (Decimal('601.95'), '602.0', 602, 602),
#  (Decimal('42.67'), '42.7', 43, 43),
#  (Decimal('42.50'), '42.5', 43, 43),
#  (Decimal('662.00'), '662.0', 662, 662),
#  (Decimal('16.33'), '16.3', 16, 16),
#  (Decimal('6.00'), '6.0', 6, 6),
#  (Decimal('856.92'), '856.9', 857, 857),
#  (Decimal('9.95'), '10.0', 10, 10),
#  (Decimal('10.00'), '10.0', 10, 10),
#  (Decimal('104.00'), '104.0', 104, 104),
#  (Decimal('116.54'), '116.5', 117, 117),
#  (Decimal('6.00'), '6.0', 6, 6),
#  (Decimal('4901.26'), '4,901.3', 4901, 4901),
#  (Decimal('108.25'), '108.3', 108, 108),
# ...

# %%
# %%sql #
#
# SELECT invoice_date,
#   CAST(invoice_date AS DATETIME),
#   CAST(invoice_date AS CHAR(7))
# FROM Invoices;
# Out:
#  * mysql+pymysql://w-alkao:***@localhost
# 119 rows affected.
# [(datetime.date(2018, 8, 3), datetime.datetime(2018, 8, 3, 0, 0), '2018-08'),
#  (datetime.date(2018, 8, 3), datetime.datetime(2018, 8, 3, 0, 0), '2018-08'),
#  (datetime.date(2018, 8, 2), datetime.datetime(2018, 8, 2, 0, 0), '2018-08'),
#  (datetime.date(2018, 8, 2), datetime.datetime(2018, 8, 2, 0, 0), '2018-08'),
#  (datetime.date(2018, 8, 1), datetime.datetime(2018, 8, 1, 0, 0), '2018-08'),
#  (datetime.date(2018, 8, 1), datetime.datetime(2018, 8, 1, 0, 0), '2018-08'),
#  (datetime.date(2018, 8, 1), datetime.datetime(2018, 8, 1, 0, 0), '2018-08'),
#  (datetime.date(2018, 7, 31), datetime.datetime(2018, 7, 31, 0, 0), '2018-07'),
#  (datetime.date(2018, 7, 30), datetime.datetime(2018, 7, 30, 0, 0), '2018-07'),
#  (datetime.date(2018, 7, 28), datetime.datetime(2018, 7, 28, 0, 0), '2018-07'),
#  (datetime.date(2018, 7, 25), datetime.datetime(2018, 7, 25, 0, 0), '2018-07'),
# ...

# %% [markdown]
# ### The end...
